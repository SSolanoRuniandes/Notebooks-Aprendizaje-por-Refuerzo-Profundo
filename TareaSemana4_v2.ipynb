# %% [markdown]
# <a href="https://colab.research.google.com/github/SSolanoRuniandes/Notebooks-Aprendizaje-por-Refuerzo-Profundo/blob/main/TareaSemana4_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![MAIA banner](https://raw.githubusercontent.com/MAIA4361-Aprendizaje-refuerzo-profundo/Notebooks_Tareas/main/Images/Aprendizaje_refuerzo_profundo_Banner_V1.png)
#
# # <h1><center>Tarea Tutorial - Semana 4 <a href="https://colab.research.google.com/github/SSolanoRuniandes/Notebooks-Aprendizaje-por-Refuerzo-Profundo/blob/main/TareaSemana4.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" width="140" align="center"/></a></center></h1>
#
# <center><h1>REINFORCE</h1></center>
#
# Este tutorial pretende introducir uno de los primeros algoritmos de gradiente de política: REINFORCE. Nuevamente, para ilustrar el funcionamiento y desempeño del algoritmo, se hará uso de un problema basado en un juego de Atari, donde el agente aprenderá directamente de las imágenes del juego. Al mismo tiempo, se profundizará en los beneficios que tiene la utilización de <i>baselines</i> durante el entrenamiento. Para ello, en este notebook se utiliza la librería Gymnasium, que incluye el juego de ________________, y una implementación de REINFORCE realizada para PyTorch.
#
#
# # Tabla de Contenidos
# 1. [Objetivos de Aprendizaje](#scrollTo=Objetivos_de_Aprendizaje)
# 2. [Marco Teórico](#scrollTo=Marco_Te_rico)
# 3. [Instalación de Librerías](#scrollTo=Instalaci_n_de_Librer_as)
# 4. [Familiarización con el Entorno de Gym](#scrollTo=Familiarizaci_n_con_el_Entorno_de_Gym)
# 5. [REINFORCE](#scrollTo=REINFORCE)
# 6. [REINFORCE con <i>baseline</i>](#scrollTo=REINFORCE_con_baseline)
# 7. [Reflexiones Finales](#scrollTo=Reflexiones_Finales)
# 8. [Referencias](#scrollTo=Referencias)

# %% [markdown]
# # Objetivos de Aprendizaje
#
# Este tutorial tiene como objetivo:
#
#
# *   Intorducir una familia distinta de algoritmos de aprendizaje por refuerzo: algoritmos de gradiente de política.
# *   Comprender las bases teóricas y práticas del funcionamiento del algoritmo de REIFORCE.
# *   Exponer las ventajas que tiene la inclusión de <i>baselines</i> dentro del entrenamiento de algoritmos de aprendizaje por refuerzo.

# %% [markdown]
# # Marco Teórico
#
# Hasta ahora, los algoritmos de aprendizaje por refuerzo que se han explorado se basan en aprender y estimar una función de valor para cada acción, por lo que reciben el nombre de métodos de valor-acción (<i>action-value methods</i>). Es decir, las políticas aprendidas en estos métodos dependen directamente de los estimativos de la función de valor-acción ($Q(s,a)$). Sin embargo, existe otra familia de algoritmos que siguen un método de gradiente de política (<i>policy gradient methods</i>), que directamente aprenden una política parametrizada con la capacidad de seleccionar acciones sin la necesidad de estimar una función de valor. Una función de valor puede ser todavía utilizada para aprender el parámetro de la política, pero no se requiere para seleccionar la acción. [1]
#
# Por convención de notación, se utiliza $\theta$ para referirse a un vector de parámetros de la política. Entonces se puede escribir que la política, corresponde a la probabilidad de elegir una acción dado un estado y el vector de parámetros: $\pi(a|s,\theta) = Pr(A_t=a|S_t=s, \theta_t=\theta)$. La forma en que un algoritmo aprende y actualiza el vector de parámetros $\theta$ se basa en el gradiente de alguna métrica de desempeño escalar $J(\theta)$. Este método busca maximizar el desempeño, así que se tiene un ascenso de gradiente en $J$, como se muestra en la Ecuación (1). Se utiliza la notación $\widehat{\nabla J(\theta_t)}$ para denotar que el gradiente en realidad se calcula utilizando un estimativo estocástico. [1]
#
# <center> $\theta_{t+1}=\theta + \alpha \widehat{\nabla J(\theta_t)}$ &emsp;&emsp;&emsp;$(1)$ </center>
#
# Otro elemento importante a tener en cuenta es el teorema de gradiente de política (policy gradient theorem), mostrado en la Ecuación (2). En este teorema, se establece que existe una proporcionalidad entre el gradiente de la función $J(\theta)$ y una expresión analítica dependiente de los parámetros de la política ($\theta$) y que se puede muestrear directamente a partir de la interacción con el ambiente a medida que se mejora la política.
# Esto en últimas permite encontrar la máxima dirección de crecimiento de $J(\theta)$ y ajustar los parámetros utilizando una constante de proporcionalidad $\alpha$ como se escribió en la Ecuación (1).
#
# <center> $\nabla J(\theta) \propto \sum_s \mu(s) \sum_a q_\pi(s, a) \nabla \pi(a|s, \theta)$ &emsp;&emsp;&emsp;$(2)$ </center>
#
# El algoritmo de REINFORCE, un algoritmo de gradiente de política, utiliza la regla de actualización de la Ecuación (3), estimando el gradiente estocástico utilizando el retorno $G_t$:
#
# <center> $\theta_{t+1} \doteq \theta_t + \alpha G_t \frac{\nabla \pi(A_t | S_t, \theta_t)}{\pi(A_t | S_t, \theta_t)}$ &emsp;&emsp;&emsp;$(3)$ </center>
#
# En esta actualización, cada incremento es proporcional al producto del retorno $G_t$ y un vector: el gradiente de la probabilidad de escoger la acción tomada dividida por la probabilidad de escoger dicha acción. Este vector corresponde a la dirección en el espacio de parámetros en la cual crece mayormente la probabilidad de escoger la acción $A_t$ en futuras visitas al estado $S_t$. La actualización es proporcional al retorno $G_t$, favoreciendo las acciones que generan mayor recompensa a largo plazo, y es inversamente proporcional a la probabilidad de escoger la acción, no favoreciendo así incorrectamente a acciones que se eligen frecuentemente. Debido a que REINFORCE utiliza el retorno completo desde un tiempo $t$, que incluye todas las recompensas vistas hasta el final del episodio, se dice que entonces REINFORCE es también un método de Monte Carlo. [1]
#
# Finalmente, se consigue una variación de la regla de actualización de REINFORCE si se incluye un <i>baseline</i>, como muestra la Ecuación (4). Incluir un baseline no cambia el valor esperado de la actualización, pero sí puede tener un efecto significativo en la varianza del aprendizaje, reduciéndola significativamente y haciendo el entrenamiento más estable. Para el caso de un MDP, dicho baseline debería variar con el estado, por lo cual una selección típica es utilizar una función de valor de estado $\hat{v}(s,\text{w})$, donde $\text{w}$ es un vector de pesos aprendido por otro algoritmo de valor-acción. [1]
#
# <center> $\theta_{t+1} \doteq \theta_t + \alpha (G_t-b(S_t)) \frac{\nabla \pi(A_t | S_t, \theta_t)}{\pi(A_t | S_t, \theta_t)}$ &emsp;&emsp;&emsp;$(4)$ </center>

# %% [markdown]
# # Instalación de Librerías
#
# En este tutorial se va a utilizar un juego de Atari 2600: <i>______</i>. Este videojuego ya se encuentra incluido en los ambientes de Atari de la librería Gymnasium. También se requiere instalar correctamente PyTorch para el uso de redes neuronales.
#
# Antes de comenzar, se sugiere elegir un entorno de simulación acelerado por GPU. En el caso de Colab gratuito, debería elegir el entorno de T4. Para ello diríjase a:
#
# `Entorno de Ejecución > Cambiar Tipo de Entorno de Ejecución > GPU T4`
#
#
# ![DobleDQNdF](https://raw.githubusercontent.com/MAIA4361-Aprendizaje-refuerzo-profundo/Notebooks_Tareas/main/Images/t4.png)
#
#
# Después, ejecute el siguiente bloque de código para instalar todas las librerías y herramientas necesarias.

# %%
#Descarga librerías no incluidas en Colab usando pip
#!pip3 uninstall --yes torch torchaudio torchvision torchtext torchdata #Para compatibilidad de PyTorch
# !pip3 install torch torchaudio torchvision torchtext torchdata #Instala PyTorch
# !pip install ale-py #ALE se utiliza para el ambiente de Atari
# !pip install "gymnasium[atari,accept-rom-license]" stable-baselines3 autorom renderlab -q #Gymnasium, envs de Atari y ROM
# !AutoROM --accept-license
# !pip install renderlab #usado para renderizar gym
# !pip install stable_baselines3 #Stable Baselines3 -> Framework de Reinforcement Learning

#Importa estas librerías
import torch #Importa herramientas de PyTorch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.distributions import Categorical
import gymnasium #importa la libreria de gymnasium con las simulaciones
import renderlab #importa renderlab para los videos
import stable_baselines3 #importa Stable Baselines3
from stable_baselines3.common.env_util import make_atari_env #importa make_atari_env para escala de grises
from stable_baselines3.common.vec_env import DummyVecEnv, VecFrameStack #importa VecFrameStack para apilar frames y acelerar así el entrenamiento
import ale_py #importa ale para los ambientes de Atari
from gymnasium.wrappers import TimeLimit #importa timelimit para acortar los episodios
from collections import deque #importa para ajustar los videos con VecFrameStack
import cv2 #importa para ajustar los videos con VecFrameStack

#!Importante:
gymnasium.register_envs(ale_py) #Hay que registrar los entornos de ALE manualmente!!!

#Importa otras librerías básicas
import numpy as np
import matplotlib.pyplot as plt
import random
import math
import pandas as pd
import sys
import argparse
from itertools import count

#Limpia los registros generados
from IPython.display import clear_output
clear_output()
print("Todas las librerías han sido instaladas correctamente.")
# Out:
# Todas las librerías han sido instaladas correctamente.

# %% [markdown]
# # Familiarización con el Entorno de Gym

# %% [markdown]
# ## Ejemplo

# %%
#Parámetros del ambiente
mode=0
difficulty=0

env_render = gymnasium.make("ALE/Breakout-v5", render_mode="rgb_array", mode=mode, difficulty=difficulty) #Se crea el ambiente.
env_render = TimeLimit(env_render, max_episode_steps=500)
env_render = renderlab.RenderFrame(env_render, "./output") #Se crea una copia que se pueda renderizar con renderlab


terminated = False #Inicializa una condición para el loop
truncated = False #Inicializa una condición para el loop
total_reward=0 #Inicializa contador del retorno

obs , info = env_render.reset() #Se reinicia el estado para comenzar. En obs se almacena el estado observado (continuo, 2 dimensiones)
obs, reward, terminated, truncated, info = env_render.step(1) #Se iuni
while not (terminated or truncated): #Simula hasta que termine la partida
  action = random.choice([0, 1, 2, 3])  # Elige una acción aleatoria
  obs, reward, terminated, truncated, info = env_render.step(action)
  total_reward += reward

print("Recompensa obtenida en el episodio:",total_reward) #Se imprime la recompensa obtenida
print("\n\n")

env_render.play() #Con esta función se obtiene el video de la simulación
# Out:
# Recompensa obtenida en el episodio: 0.0
#
#
#
# Moviepy - Building video temp-{start}.mp4.
# Moviepy - Writing video temp-{start}.mp4
# Moviepy - Done !
# Moviepy - video ready temp-{start}.mp4
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %%
#Parámetros del ambiente
mode=0
difficulty=0

env_render = gymnasium.make("ALE/Breakout-v5", render_mode="rgb_array", mode=mode, difficulty=difficulty) #Se crea el ambiente.
env_render = TimeLimit(env_render, max_episode_steps=500)
env_render = renderlab.RenderFrame(env_render, "./output") #Se crea una copia que se pueda renderizar con renderlab


terminated = False #Inicializa una condición para el loop
truncated = False #Inicializa una condición para el loop
total_reward=0 #Inicializa contador del retorno
vidas=0


obs , info = env_render.reset() #Se reinicia el estado para comenzar. En obs se almacena el estado observado (continuo, 2 dimensiones)
obs, reward, terminated, truncated, info = env_render.step(1) #Se iuni



while not (terminated or truncated): #Simula hasta que termine la partida
  #print(env_render.unwrapped.ale.lives())
  nuevas_vidas=env_render.unwrapped.ale.lives()
  if(nuevas_vidas==vidas):
    action = random.choice([0, 2, 3])  # Elige una acción aleatoria
  else:
    action = 1
  vidas=nuevas_vidas
  obs, reward, terminated, truncated, info = env_render.step(action)
  total_reward += reward

print("Recompensa obtenida en el episodio:",total_reward) #Se imprime la recompensa obtenida
print("\n\n")

env_render.play() #Con esta función se obtiene el video de la simulación
# Out:
# Recompensa obtenida en el episodio: 3.0
#
#
#
# Moviepy - Building video temp-{start}.mp4.
# Moviepy - Writing video temp-{start}.mp4
# Moviepy - Done !
# Moviepy - video ready temp-{start}.mp4
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %%
class AutoFireWrapper(gymnasium.Wrapper):
    def __init__(self, env):
        super().__init__(env)
        self.last_lives = 0

    def reset(self, **kwargs):
        obs, info = self.env.reset(**kwargs)
        self.last_lives = self.env.unwrapped.ale.lives()
        # Ejecutar un paso FIRE si es necesario (al inicio la bola está quieta)
        obs, _, terminated, truncated, info = self.env.step(1)
        return obs, info

    def step(self, action):
        current_lives = self.env.unwrapped.ale.lives()

        # Si el número de vidas ha cambiado, disparar
        if current_lives < self.last_lives:
            self.last_lives = current_lives
            # Forzar acción FIRE
            obs, reward, terminated, truncated, info = self.env.step(1)
            # Acumular reward de esta acción y continuar con la real
            obs2, reward2, terminated2, truncated2, info2 = self.env.step(action)
            return obs2, reward + reward2, terminated or terminated2, truncated or truncated2, info2
        else:
            self.last_lives = current_lives
            return self.env.step(action)

#Parámetros del ambiente
mode=0
difficulty=0

env_render = gymnasium.make("ALE/Breakout-v5", render_mode="rgb_array", mode=mode, difficulty=difficulty) #Se crea el ambiente.
env_render = AutoFireWrapper(env_render)
env_render = TimeLimit(env_render, max_episode_steps=500)
env_render = renderlab.RenderFrame(env_render, "./output") #Se crea una copia que se pueda renderizar con renderlab


terminated = False #Inicializa una condición para el loop
truncated = False #Inicializa una condición para el loop
total_reward=0 #Inicializa contador del retorno

obs , info = env_render.reset() #Se reinicia el estado para comenzar. En obs se almacena el estado observado (continuo, 2 dimensiones)
obs, reward, terminated, truncated, info = env_render.step(1) #Se iuni
while not (terminated or truncated): #Simula hasta que termine la partida
  action = random.choice([0, 2, 3])  # Elige una acción aleatoria
  obs, reward, terminated, truncated, info = env_render.step(action)
  total_reward += reward

print("Recompensa obtenida en el episodio:",total_reward) #Se imprime la recompensa obtenida
print("\n\n")

env_render.play() #Con esta función se obtiene el video de la simulación
# Out:
# Recompensa obtenida en el episodio: 3.0
#
#
#
# Moviepy - Building video temp-{start}.mp4.
# Moviepy - Writing video temp-{start}.mp4
# Moviepy - Done !
# Moviepy - video ready temp-{start}.mp4
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %%
# Ejecute una partida con dificultad 1 y modo 7

# =====================================================
# COMPLETAR ===========================================
#

# =====================================================

# %% [markdown]
# #REINFORCE

# %%
class Policy_1(nn.Module):
    def __init__(self, input_dim, output_dim):
        super(Policy_1, self).__init__()
        self.affine1 = nn.Linear(input_dim, 128)
        self.dropout = nn.Dropout(p=0.6)
        self.affine2 = nn.Linear(128, output_dim)

        self.saved_log_probs = []
        self.rewards = []

    def forward(self, x):
        x = self.affine1(x)
        x = self.dropout(x)
        x = F.relu(x)
        action_scores = self.affine2(x)
        return F.softmax(action_scores, dim=1)

class REINFORCE_1:
  def __init__(self,env_name, use_baseline=True, max_steps_per_episode=10000):
    self.gamma=0.99
    self.seed=543
    self.render=False
    self.log_interval=10
    self.env_name=env_name
    self.max_steps_per_episode=max_steps_per_episode
    self.use_baseline=use_baseline


    self.env = gymnasium.make(self.env_name)
    obs, _ = self.env.reset(seed=self.seed)
    torch.manual_seed(self.seed)

    input_dim = obs.shape[0]
    if hasattr(self.env.action_space, 'n'):
      output_dim = self.env.action_space.n
    else:
      raise ValueError("El espacio de acciones debe ser discreto.")

    self.policy = Policy_1(input_dim, output_dim)
    self.optimizer = optim.Adam(self.policy.parameters(), lr=1e-2)
    self.eps = np.finfo(np.float32).eps.item()

  def select_action(self, state):
      state = torch.from_numpy(state).float().unsqueeze(0)
      probs = self.policy(state)
      m = Categorical(probs)
      action = m.sample()
      self.policy.saved_log_probs.append(m.log_prob(action))
      return action.item()
  """
  def finish_episode(self):
      R = 0
      policy_loss = []
      returns = deque()
      for r in self.policy.rewards[::-1]:
          R = r + self.gamma * R
          returns.appendleft(R)
      returns = torch.tensor(returns)
      returns = (returns - returns.mean()) / (returns.std() + self.eps)
      for log_prob, R in zip(self.policy.saved_log_probs, returns):
          policy_loss.append(-log_prob * R)
      self.optimizer.zero_grad()
      policy_loss = torch.cat(policy_loss).sum()
      policy_loss.backward()
      self.optimizer.step()
      del self.policy.rewards[:]
      del self.policy.saved_log_probs[:]
  """
  def finish_episode(self):
    #Version con Baselines
    R = 0
    policy_loss = []
    returns = deque()

    # Calculamos el baseline como el promedio de las recompensas (ESTO HAY QUE CAMBIARLO A ALGO MÁS ÚTIL!!!!)
    if(self.use_baseline):
      baseline = torch.mean(torch.tensor(self.policy.rewards, dtype=torch.float32))
    else:
      baseline=0 #Si self.use_baselines es False, coloca baseline en 0 que es efectivavmente no usar baselines

    for r in self.policy.rewards[::-1]:
        R = r + self.gamma * R
        returns.appendleft(R)
    returns = torch.tensor(returns)

    # Normalizamos las recompensas con respecto al baseline
    returns = returns - baseline  # Descontamos el baseline de las recompensas

    returns = (returns - returns.mean()) / (returns.std() + self.eps)
    for log_prob, R in zip(self.policy.saved_log_probs, returns):
        policy_loss.append(-log_prob * R)
    self.optimizer.zero_grad()
    policy_loss = torch.cat(policy_loss).sum()
    policy_loss.backward()
    self.optimizer.step()
    del self.policy.rewards[:]
    del self.policy.saved_log_probs[:]

  def train(self):
    running_reward = 10
    for i_episode in count(1):
        state, _ = self.env.reset()
        ep_reward = 0
        for t in range(1, self.max_steps_per_episode):  # Don't infinite loop while learning
            action = self.select_action(state)
            state, reward, done, _, _ = self.env.step(action)
            self.policy.rewards.append(reward)
            ep_reward += reward
            if done:
                break

        running_reward = 0.05 * ep_reward + (1 - 0.05) * running_reward
        self.finish_episode()
        if i_episode % self.log_interval == 0:
            print('Episode {}\tLast reward: {:.2f}\tAverage reward: {:.2f}'.format(
                  i_episode, ep_reward, running_reward))
        if hasattr(self.env.spec, 'reward_threshold') and running_reward > self.env.spec.reward_threshold:
            print("Solved! Running reward is now {} and "
                  "the last episode runs to {} time steps!".format(running_reward, t))
            break

  def video(self):
    env_prueba_1 = gymnasium.make(self.env_name, render_mode="rgb_array") #Esta línea de código crea el ambiente.
    env_prueba_1 = renderlab.RenderFrame(env_prueba_1, "./output") #Esta línea se utiliza para crear una copia que se pueda renderizar con renderlab

    obs , info = env_prueba_1.reset() #Se reinicia el estado para comenzar. En obs se almacena el estado observado (continuo, 4 dimensiones)
    terminated = False #Inicializa una condición para el loop
    truncated = False #Inicializa una condición para el loop
    total_reward=0 #Inicializa contador del retorno

    while not (terminated or truncated): #Simula hasta que el poste caiga o hasta alcanzar 500 episodios (configuración de CartPole-v1)
      action=self.select_action(obs)
      obs, reward, terminated, truncated , info = env_prueba_1.step(action) #Con la función step el ambiente da un paso. Se obtiene el estado, recompensa y banderas de información
      total_reward+=reward #Llevamos una cuenta de la recompensa total


    print("\n\n\n\n")
    print("Recompensa obtenida en el episodio:",total_reward) #Después de terminar el episodio, imprimios la recompensa acumulada total obtenida
    print("\n\n")

    env_prueba_1.play() #Con esta función se obtiene el video de la simulación


print("Sin Baseline")
agente_cartpole=REINFORCE_1('CartPole-v1', use_baseline=False)
agente_cartpole.train()
agente_cartpole.video()

print("Con Baseline")
agente_cartpole2=REINFORCE_1('CartPole-v1')
agente_cartpole2.train()
agente_cartpole2.video()
# Out:
# Sin Baseline
# Episode 10	Last reward: 35.00	Average reward: 12.44
# Episode 20	Last reward: 35.00	Average reward: 21.75
# Episode 30	Last reward: 16.00	Average reward: 27.05
# Episode 40	Last reward: 30.00	Average reward: 33.14
# Episode 50	Last reward: 77.00	Average reward: 37.71
# Episode 60	Last reward: 85.00	Average reward: 54.15
# Episode 70	Last reward: 118.00	Average reward: 69.26
# Episode 80	Last reward: 66.00	Average reward: 76.18
# Episode 90	Last reward: 84.00	Average reward: 89.80
# Episode 100	Last reward: 39.00	Average reward: 71.23
# Episode 110	Last reward: 32.00	Average reward: 62.12
# Episode 120	Last reward: 72.00	Average reward: 59.22
# Episode 130	Last reward: 93.00	Average reward: 77.14
# Episode 140	Last reward: 172.00	Average reward: 87.55
# Episode 150	Last reward: 232.00	Average reward: 92.18
# Episode 160	Last reward: 113.00	Average reward: 103.46
# Episode 170	Last reward: 213.00	Average reward: 115.83
# Episode 180	Last reward: 82.00	Average reward: 140.00
# Episode 190	Last reward: 36.00	Average reward: 95.89
# Episode 200	Last reward: 33.00	Average reward: 67.37
# Episode 210	Last reward: 43.00	Average reward: 54.21
# Episode 220	Last reward: 56.00	Average reward: 57.36
# Episode 230	Last reward: 183.00	Average reward: 73.38
# Episode 240	Last reward: 649.00	Average reward: 283.99
# Episode 250	Last reward: 320.00	Average reward: 275.09
# Solved! Running reward is now 562.9921741898453 and the last episode runs to 3533 time steps!
#
#
#
#
#
# Recompensa obtenida en el episodio: 500.0
#
#
#
# Moviepy - Building video temp-{start}.mp4.
# Moviepy - Writing video temp-{start}.mp4
# Moviepy - Done !
# Moviepy - video ready temp-{start}.mp4
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>
# Con Baseline
# Episode 10	Last reward: 35.00	Average reward: 12.44
# Episode 20	Last reward: 35.00	Average reward: 21.75
# Episode 30	Last reward: 16.00	Average reward: 27.05
# Episode 40	Last reward: 30.00	Average reward: 33.14
# Episode 50	Last reward: 77.00	Average reward: 37.71
# Episode 60	Last reward: 85.00	Average reward: 54.15
# Episode 70	Last reward: 118.00	Average reward: 69.26
# Episode 80	Last reward: 66.00	Average reward: 76.18
# Episode 90	Last reward: 84.00	Average reward: 89.80
# Episode 100	Last reward: 39.00	Average reward: 71.23
# Episode 110	Last reward: 32.00	Average reward: 62.12
# Episode 120	Last reward: 72.00	Average reward: 59.22
# Episode 130	Last reward: 54.00	Average reward: 65.85
# Episode 140	Last reward: 131.00	Average reward: 72.90
# Episode 150	Last reward: 79.00	Average reward: 77.47
# Episode 160	Last reward: 87.00	Average reward: 84.25
# Episode 170	Last reward: 48.00	Average reward: 81.84
# Episode 180	Last reward: 66.00	Average reward: 71.30
# Episode 190	Last reward: 69.00	Average reward: 71.32
# Episode 200	Last reward: 58.00	Average reward: 76.40
# Episode 210	Last reward: 45.00	Average reward: 70.58
# Episode 220	Last reward: 51.00	Average reward: 73.44
# Episode 230	Last reward: 79.00	Average reward: 74.31
# Episode 240	Last reward: 92.00	Average reward: 84.93
# Episode 250	Last reward: 104.00	Average reward: 97.26
# Episode 260	Last reward: 186.00	Average reward: 98.79
# Episode 270	Last reward: 252.00	Average reward: 148.35
# Episode 280	Last reward: 124.00	Average reward: 209.81
# Episode 290	Last reward: 101.00	Average reward: 168.30
# Episode 300	Last reward: 40.00	Average reward: 127.12
# Episode 310	Last reward: 68.00	Average reward: 92.52
# Episode 320	Last reward: 84.00	Average reward: 91.12
# Episode 330	Last reward: 9999.00	Average reward: 636.86
# Solved! Running reward is now 636.8581135134971 and the last episode runs to 9999 time steps!
#
#
#
#
#
# Recompensa obtenida en el episodio: 500.0
#
#
#
# Moviepy - Building video temp-{start}.mp4.
# Moviepy - Writing video temp-{start}.mp4
# Moviepy - Done !
# Moviepy - video ready temp-{start}.mp4
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %%
class Policy_2(nn.Module):
    def __init__(self):
        super(Policy_2, self).__init__()
        self.conv1 = nn.Conv2d(4, 32, kernel_size=8, stride=4)
        self.bn1 = nn.BatchNorm2d(32)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=4, stride=2)
        self.bn2 = nn.BatchNorm2d(64)
        self.conv3 = nn.Conv2d(64, 64, kernel_size=3, stride=1)
        self.bn3 = nn.BatchNorm2d(64)

        self.fc1 = nn.Linear(64 * 7 * 7, 512)
        self.fc2 = nn.Linear(512, 4)

        self.saved_log_probs = []
        self.rewards = []

    def forward(self, x):
      x = F.relu(self.conv1(x))
      x = F.relu(self.conv2(x))
      x = F.relu(self.conv3(x))

      x = x.reshape(x.size(0), -1)  # Reemplazo de .view()
      x = F.relu(self.fc1(x))
      return F.softmax(self.fc2(x), dim=1)

class REINFORCE_2:
  def __init__(self, use_baseline=True, max_steps_per_episode=10000, max_training_episodes=1000):
    self.gamma=0.99
    self.seed=543
    self.render=False
    self.log_interval=100
    #self.env_name=env_name
    self.max_steps_per_episode=max_steps_per_episode
    self.max_training_episodes=max_training_episodes
    self.use_baseline=use_baseline

    #Crea el ambiente con escala de grises y apilando 4 frames
    self.env = make_atari_env("ALE/Breakout-v5",n_envs=1,seed=0,env_kwargs={"mode": 0, "difficulty": 0})
    self.env = VecFrameStack(self.env, n_stack=4)

    #self.env = gymnasium.make("ALE/Breakout-v5", mode=0, difficulty=0) #Se crea el ambiente.
    #self.env = TimeLimit(self.env, max_episode_steps=max_steps_per_episode)

    #obs, _ = self.env.reset(seed=self.seed)
    torch.manual_seed(self.seed)

    input_dim = obs.shape[0]
    if hasattr(self.env.action_space, 'n'):
      output_dim = self.env.action_space.n
    else:
      raise ValueError("El espacio de acciones debe ser discreto.")

    self.policy = Policy_2()  # Asegúrate de que es la clase adaptada con CNN
    self.optimizer = optim.Adam(self.policy.parameters(), lr=3e-4)  # lr más bajo suele funcionar mejor en imágenes
    self.eps = np.finfo(np.float32).eps.item()  # Para evitar divisiones por cero

  def select_action(self, state):
      # Convert the state (environment image) into a PyTorch tensor
      # state original: (1, 84, 84, 4)
      state = torch.from_numpy(state).float()
      state = state.permute(0, 3, 1, 2)  # state after: (1, 4, 84, 84)


      epsilon = 0.1
      probs = self.policy(state)

      if random.random() < epsilon:
          action = torch.tensor([random.randrange(probs.shape[-1])])
      else:
          m = Categorical(probs)
          action = m.sample()
          self.policy.saved_log_probs.append(m.log_prob(action))

      return action.item()

  def finish_episode(self):
    #Version con Baselines
    R = 0
    policy_loss = []
    returns = deque()

    # Calculamos el baseline como el promedio de las recompensas (ESTO HAY QUE CAMBIARLO A ALGO MÁS ÚTIL!!!!)
    if(self.use_baseline):
      baseline = torch.mean(torch.tensor(self.policy.rewards, dtype=torch.float32))
    else:
      baseline=0 #Si self.use_baselines es False, coloca baseline en 0 que es efectivavmente no usar baselines

    for r in self.policy.rewards[::-1]:
        R = r + self.gamma * R
        returns.appendleft(R)
    returns = np.array(returns)  # Convertir la lista a un único numpy array
    returns = torch.tensor(returns)

    # Normalizamos las recompensas con respecto al baseline
    returns = returns - baseline  # Descontamos el baseline de las recompensas

    returns = (returns - returns.mean()) / (returns.std() + self.eps)
    for log_prob, R in zip(self.policy.saved_log_probs, returns):
      if log_prob is not None:
          policy_loss.append(-log_prob * R)

    self.optimizer.zero_grad()

    if len(policy_loss) == 0:
        return  # No se actualiza porque no hubo acciones basadas en la política

    policy_loss = torch.cat(policy_loss).sum()
    policy_loss.backward()
    self.optimizer.step()
    del self.policy.rewards[:]
    del self.policy.saved_log_probs[:]

  def train(self):
    running_reward = 0
    cumulative_episodes_reward=0
    for i_episode in range(1,self.max_training_episodes+1):
        state = self.env.reset()
        ep_reward = 0
        for t in range(1, self.max_steps_per_episode):  # Don't infinite loop while learning
            action = self.select_action(state)
            state, reward, done, _ = self.env.step([action])
            self.policy.rewards.append(reward)
            ep_reward += np.array(reward).item()
            if done:
              break

        running_reward = 0.05 * ep_reward + (1 - 0.05) * running_reward
        cumulative_episodes_reward += ep_reward
        #print("Episode {} Reward: {} and Running Reward: {}".format(i_episode,float(ep_reward),running_reward))
        self.finish_episode()
        if i_episode % self.log_interval == 0:
          print('Episode {} completed.\tLast Reward: {:.2f}\tLast 100 Episodes Avarage reward: {:.2f}\tRunning reward: {:.2f}'.format(
                  i_episode, ep_reward, cumulative_episodes_reward/100, running_reward))
          cumulative_episodes_reward=0
        #if self.env.spec.reward_threshold is not None and running_reward > self.env.spec.reward_threshold:
        if running_reward > 1:
          print("Solved! Running reward is now {} and "
                  "the last episode runs to {} time steps!".format(running_reward, t))
          break

  def video(self):
    # Crea un entorno para renderizar
    env = gymnasium.make("ALE/Breakout-v5", render_mode="rgb_array", mode=0, difficulty=0)
    env = renderlab.RenderFrame(env, "./output")

    # Frame stack manual para el modelo (apilamos en gris 84x84)
    frame_stack = deque(maxlen=4)

    # Reset del entorno
    obs, info = env.reset()

    # Procesa una copia del frame sólo para el modelo
    def preprocess(obs):
        gray = obs.mean(axis=2).astype(np.uint8)  # escala de grises
        resized = cv2.resize(gray, (84, 84), interpolation=cv2.INTER_AREA)
        return resized

    # Llena el frame stack inicial
    preprocessed = preprocess(obs)
    for _ in range(4):
        frame_stack.append(preprocessed)

    terminated = False
    truncated = False
    total_reward = 0

    # Loop de simulación
    while not (terminated or truncated):
        # Convertir la pila de frames a la forma (4, 84, 84)
        stacked_obs = np.stack(frame_stack, axis=0)  # (4, 84, 84)

        # Cambiar el orden de las dimensiones a (1, 4, 84, 84) -> (batch_size, channels, height, width)
        stacked_obs = np.expand_dims(stacked_obs, axis=0)  # (1, 4, 84, 84)
        stacked_obs = np.transpose(stacked_obs, (0, 2, 3, 1))  # (1, 84, 84, 4)

        # Elige la acción
        action=self.select_action(stacked_obs)

        # Avanza en el entorno real manteniendo la continuidad en el video
        obs, reward, terminated, truncated, info = env.step(action)
        total_reward += reward

        # Actualiza el stack sólo para el modelo
        preprocessed = preprocess(obs)
        frame_stack.append(preprocessed)

    print("Recompensa obtenida en el episodio:", total_reward)
    env.play()


agente_breakout=REINFORCE_2(use_baseline=False,max_steps_per_episode=500, max_training_episodes=10000)
agente_breakout.train()
agente_breakout.video()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-9afa396c7ef5> in <cell line: 0>()
#     190
#     191 agente_breakout=REINFORCE_2(use_baseline=False,max_steps_per_episode=500, max_training_episodes=10000)
# --> 192 agente_breakout.train()
#     193 agente_breakout.video()
#
# <ipython-input-26-9afa396c7ef5> in train(self)
#     128         cumulative_episodes_reward += ep_reward
#     129         #print("Episode {} Reward: {} and Running Reward: {}".format(i_episode,float(ep_reward),running_reward))
# --> 130         self.finish_episode()
#     131         if i_episode % self.log_interval == 0:
#     132           print('Episode {} completed.\tLast Reward: {:.2f}\tLast 100 Episodes Avarage reward: {:.2f}\tRunning reward: {:.2f}'.format(
#
# <ipython-input-26-9afa396c7ef5> in finish_episode(self)
#     107     policy_loss = torch.cat(policy_loss).sum()
#     108     policy_loss.backward()
# --> 109     self.optimizer.step()
#     110     del self.policy.rewards[:]
#     111     del self.policy.saved_log_probs[:]
#
# /usr/local/lib/python3.11/dist-packages/torch/optim/optimizer.py in wrapper(*args, **kwargs)
#     491                             )
#     492
# --> 493                 out = func(*args, **kwargs)
#     494                 self._optimizer_step_code()
#     495
#
# /usr/local/lib/python3.11/dist-packages/torch/optim/optimizer.py in _use_grad(self, *args, **kwargs)
#      89             torch.set_grad_enabled(self.defaults["differentiable"])
#      90             torch._dynamo.graph_break()
# ---> 91             ret = func(self, *args, **kwargs)
#      92         finally:
#      93             torch._dynamo.graph_break()
#
# /usr/local/lib/python3.11/dist-packages/torch/optim/adam.py in step(self, closure)
#     242             )
#     243
# --> 244             adam(
#     245                 params_with_grad,
#     246                 grads,
#
# /usr/local/lib/python3.11/dist-packages/torch/optim/optimizer.py in maybe_fallback(*args, **kwargs)
#     152                 return disabled_func(*args, **kwargs)
#     153             else:
# --> 154                 return func(*args, **kwargs)
#     155
#     156         return maybe_fallback
#
# /usr/local/lib/python3.11/dist-packages/torch/optim/adam.py in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, differentiable, fused, grad_scale, found_inf, has_complex, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     874         func = _single_tensor_adam
#     875
# --> 876     func(
#     877         params,
#     878         grads,
#
# /usr/local/lib/python3.11/dist-packages/torch/optim/adam.py in _single_tensor_adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, grad_scale, found_inf, amsgrad, has_complex, beta1, beta2, lr, weight_decay, eps, maximize, capturable, differentiable)
#     474                 denom = (max_exp_avg_sqs[i].sqrt() / bias_correction2_sqrt).add_(eps)
#     475             else:
# --> 476                 denom = (exp_avg_sq.sqrt() / bias_correction2_sqrt).add_(eps)
#     477
#     478             param.addcdiv_(exp_avg, denom, value=-step_size)
#
# KeyboardInterrupt:

# %%
class Policy_4(nn.Module):
    def __init__(self):
        super(Policy_4, self).__init__()
        self.conv1 = nn.Conv2d(2, 32, kernel_size=8, stride=4)
        self.bn1 = nn.BatchNorm2d(32)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=4, stride=2)
        self.bn2 = nn.BatchNorm2d(64)
        self.conv3 = nn.Conv2d(64, 64, kernel_size=3, stride=1)
        self.bn3 = nn.BatchNorm2d(64)

        self.fc1 = nn.Linear(64 * 7 * 7, 512)
        self.fc2 = nn.Linear(512, 3)

        self.saved_log_probs = []
        self.rewards = []

    def forward(self, x):
      x = F.relu(self.conv1(x))
      x = F.relu(self.conv2(x))
      x = F.relu(self.conv3(x))

      x = x.reshape(x.size(0), -1)  # Reemplazo de .view()
      x = F.relu(self.fc1(x))
      return F.softmax(self.fc2(x), dim=1)

class REINFORCE_4:
  def __init__(self, use_baseline=True, max_steps_per_episode=10000, max_training_episodes=1000):
    self.gamma=1 #0.99
    self.seed=543
    self.render=False
    self.log_interval=100
    #self.env_name=env_name
    self.max_steps_per_episode=max_steps_per_episode
    self.max_training_episodes=max_training_episodes
    self.use_baseline=use_baseline

    self.vidas=-1

    #Crea el ambiente con escala de grises y apilando 4 frames
    self.env = make_atari_env("ALE/Breakout-v5",n_envs=1,seed=0,env_kwargs={"mode": 0, "difficulty": 0})
    self.env = VecFrameStack(self.env, n_stack=2)

    #self.env = gymnasium.make("ALE/Breakout-v5", mode=0, difficulty=0) #Se crea el ambiente.
    #self.env = TimeLimit(self.env, max_episode_steps=max_steps_per_episode)

    #obs, _ = self.env.reset(seed=self.seed)
    obs = self.env.reset()
    torch.manual_seed(self.seed)

    input_dim = obs.shape[0]
    if hasattr(self.env.action_space, 'n'):
      output_dim = self.env.action_space.n
    else:
      raise ValueError("El espacio de acciones debe ser discreto.")

    self.policy = Policy_4()  # Asegúrate de que es la clase adaptada con CNN
    self.optimizer = optim.Adam(self.policy.parameters(), lr=1e-5)  # lr más bajo suele funcionar mejor en imágenes
    self.eps = np.finfo(np.float32).eps.item()  # Para evitar divisiones por cero

  def select_action(self, state, vidas_actuales, epsilon=0.15):
    # Convert the state (environment image) into a PyTorch tensor
    # state original: (1, 84, 84, 2)
    state = torch.from_numpy(state).float()
    state = state.permute(0, 3, 1, 2)  # state after: (1, 2, 84, 84)


    if(self.vidas == vidas_actuales):
        if random.random() < epsilon:  # Con probabilidad epsilon, elegir acción aleatoria
          action = random.choice([0, 1, 2])  # Acción aleatoria (ajusta a tus acciones)
          #print("Acción aleatoria elegida:", action)
        else:
          # Red neuronal elige una acción
          probs = self.policy(state)
          m = Categorical(probs)
          action = m.sample()
          self.policy.saved_log_probs.append(m.log_prob(action))
          action = action.item()
          # Mapeo de la acción de la red neuronal a la acción en el juego
        action_map = {0: 0, 1: 2, 2: 3}
        action = action_map[action]
    else:
        # Acción manual (disparar)
        action = 1
        # No registrar log-prob o recompensas para este paso

    # Actualizar vidas para detectar cambios de vidas
    self.vidas = vidas_actuales

    return action

  def finish_episode(self):
    #Version con Baselines
    R = 0
    policy_loss = []
    returns = deque()

    # Calculamos el baseline como el promedio de las recompensas (ESTO HAY QUE CAMBIARLO A ALGO MÁS ÚTIL!!!!)
    if(self.use_baseline):
      baseline = torch.mean(torch.tensor(self.policy.rewards, dtype=torch.float32))
    else:
      baseline=0 #Si self.use_baselines es False, coloca baseline en 0 que es efectivavmente no usar baselines

    for r in self.policy.rewards[::-1]:
        R = r + self.gamma * R
        returns.appendleft(R)
    returns = np.array(returns)  # Convertir la lista a un único numpy array
    returns = torch.tensor(returns)

    # Normalizamos las recompensas con respecto al baseline
    returns = returns - baseline  # Descontamos el baseline de las recompensas

    returns = (returns - returns.mean()) / (returns.std() + self.eps)
    for log_prob, R in zip(self.policy.saved_log_probs, returns):
      if log_prob is not None:
          policy_loss.append(-log_prob * R)

    self.optimizer.zero_grad()

    if len(policy_loss) == 0:
        return  # No se actualiza porque no hubo acciones basadas en la política

    policy_loss = torch.cat(policy_loss).sum()
    policy_loss.backward()
    self.optimizer.step()
    del self.policy.rewards[:]
    del self.policy.saved_log_probs[:]

  def train(self):
    running_reward = 0
    cumulative_episodes_reward=0
    for i_episode in range(1,self.max_training_episodes+1):
        state = self.env.reset()
        self.vidas=-1
        ep_reward = 0
        for t in range(1, self.max_steps_per_episode):  # Don't infinite loop while learning
            vidas_actuales=self.env.envs[0].unwrapped.ale.lives()
            #print(vidas_actuales)
            action = self.select_action(state, vidas_actuales)
            #print(action)
            state, reward, done, _ = self.env.step([action])
            self.policy.rewards.append(reward)
            ep_reward += np.array(reward).item()
            if done:
              break

        running_reward = 0.05 * ep_reward + (1 - 0.05) * running_reward
        cumulative_episodes_reward += ep_reward
        #print("Episode {} Reward: {} and Running Reward: {}".format(i_episode,float(ep_reward),running_reward))
        self.finish_episode()
        if i_episode % self.log_interval == 0:
          print('Episode {} completed.\tLast Reward: {:.2f}\tLast 100 Episodes Avarage reward: {:.2f}\t\tRunning reward: {:.2f}'.format(
                  i_episode, ep_reward, cumulative_episodes_reward/100, running_reward))
          cumulative_episodes_reward=0
        #if self.env.spec.reward_threshold is not None and running_reward > self.env.spec.reward_threshold:
        if running_reward > 1:
          print("Solved! Running reward is now {} and "
                  "the last episode runs to {} time steps!".format(running_reward, t))
          break

  def video(self):
    # Crea un entorno para renderizar
    env = gymnasium.make("ALE/Breakout-v5", render_mode="rgb_array", mode=0, difficulty=0)
    env = renderlab.RenderFrame(env, "./output")

    # Frame stack manual para el modelo (apilamos en gris 84x84)
    frame_stack = deque(maxlen=2)

    # Reset del entorno
    obs, info = env.reset()

    # Procesa una copia del frame sólo para el modelo
    def preprocess(obs):
        gray = obs.mean(axis=2).astype(np.uint8)  # escala de grises
        resized = cv2.resize(gray, (84, 84), interpolation=cv2.INTER_AREA)
        return resized

    # Llena el frame stack inicial
    preprocessed = preprocess(obs)
    for _ in range(2):
        frame_stack.append(preprocessed)

    terminated = False
    truncated = False
    total_reward = 0
    self.vidas=-1

    # Loop de simulación
    while not (terminated or truncated):
        # Convertir la pila de frames a la forma (2, 84, 84)
        stacked_obs = np.stack(frame_stack, axis=0)  # (2, 84, 84)

        # Cambiar el orden de las dimensiones a (1, 2, 84, 84) -> (batch_size, channels, height, width)
        stacked_obs = np.expand_dims(stacked_obs, axis=0)  # (1, 2, 84, 84)
        stacked_obs = np.transpose(stacked_obs, (0, 2, 3, 1))  # (1, 84, 84, 2)

        # Elige la acción
        vidas_actuales=env.unwrapped.ale.lives()
        #print(vidas_actuales)
        action=self.select_action(stacked_obs, vidas_actuales, epsilon=0)

        # Avanza en el entorno real manteniendo la continuidad en el video
        obs, reward, terminated, truncated, info = env.step(action)
        total_reward += reward

        # Actualiza el stack sólo para el modelo
        preprocessed = preprocess(obs)
        frame_stack.append(preprocessed)

    print("Recompensa obtenida en el episodio:", total_reward)
    env.play()


agente_breakout=REINFORCE_4(use_baseline=False,max_steps_per_episode=5000, max_training_episodes=5000)
agente_breakout.train()
agente_breakout.video()
# Out:
# Episode 100 completed.	Last Reward: 0.00	Last 100 Episodes Avarage reward: 0.20		Running reward: 0.25
# Episode 200 completed.	Last Reward: 0.00	Last 100 Episodes Avarage reward: 0.30		Running reward: 0.37
# Episode 300 completed.	Last Reward: 0.00	Last 100 Episodes Avarage reward: 0.35		Running reward: 0.29
# Episode 400 completed.	Last Reward: 0.00	Last 100 Episodes Avarage reward: 0.11		Running reward: 0.10
# Episode 500 completed.	Last Reward: 0.00	Last 100 Episodes Avarage reward: 0.30		Running reward: 0.21
# Episode 600 completed.	Last Reward: 0.00	Last 100 Episodes Avarage reward: 0.21		Running reward: 0.18
# Episode 700 completed.	Last Reward: 1.00	Last 100 Episodes Avarage reward: 0.20		Running reward: 0.21
# Episode 800 completed.	Last Reward: 0.00	Last 100 Episodes Avarage reward: 0.36		Running reward: 0.34
# Episode 900 completed.	Last Reward: 0.00	Last 100 Episodes Avarage reward: 0.46		Running reward: 0.49
# Episode 1000 completed.	Last Reward: 0.00	Last 100 Episodes Avarage reward: 0.33		Running reward: 0.27
# Episode 1100 completed.	Last Reward: 0.00	Last 100 Episodes Avarage reward: 0.35		Running reward: 0.31
# Episode 1200 completed.	Last Reward: 0.00	Last 100 Episodes Avarage reward: 0.28		Running reward: 0.24
# Episode 1300 completed.	Last Reward: 0.00	Last 100 Episodes Avarage reward: 0.32		Running reward: 0.41
# Episode 1400 completed.	Last Reward: 1.00	Last 100 Episodes Avarage reward: 0.40		Running reward: 0.34
# Episode 1500 completed.	Last Reward: 2.00	Last 100 Episodes Avarage reward: 0.40		Running reward: 0.45
# Episode 1600 completed.	Last Reward: 0.00	Last 100 Episodes Avarage reward: 0.45		Running reward: 0.40
# Episode 1700 completed.	Last Reward: 3.00	Last 100 Episodes Avarage reward: 0.29		Running reward: 0.45
# Episode 1800 completed.	Last Reward: 0.00	Last 100 Episodes Avarage reward: 0.44		Running reward: 0.40
# Episode 1900 completed.	Last Reward: 0.00	Last 100 Episodes Avarage reward: 0.40		Running reward: 0.43
# Episode 2000 completed.	Last Reward: 1.00	Last 100 Episodes Avarage reward: 0.42		Running reward: 0.50
# Episode 2100 completed.	Last Reward: 0.00	Last 100 Episodes Avarage reward: 0.37		Running reward: 0.31
# Episode 2200 completed.	Last Reward: 0.00	Last 100 Episodes Avarage reward: 0.36		Running reward: 0.27
# Episode 2300 completed.	Last Reward: 0.00	Last 100 Episodes Avarage reward: 0.40		Running reward: 0.47
# Episode 2400 completed.	Last Reward: 0.00	Last 100 Episodes Avarage reward: 0.39		Running reward: 0.40
# Episode 2500 completed.	Last Reward: 0.00	Last 100 Episodes Avarage reward: 0.46		Running reward: 0.47
# Episode 2600 completed.	Last Reward: 1.00	Last 100 Episodes Avarage reward: 0.40		Running reward: 0.62
# Episode 2700 completed.	Last Reward: 1.00	Last 100 Episodes Avarage reward: 0.45		Running reward: 0.42
# Episode 2800 completed.	Last Reward: 0.00	Last 100 Episodes Avarage reward: 0.41		Running reward: 0.34
# Episode 2900 completed.	Last Reward: 0.00	Last 100 Episodes Avarage reward: 0.32		Running reward: 0.45
# Episode 3000 completed.	Last Reward: 2.00	Last 100 Episodes Avarage reward: 0.33		Running reward: 0.41
# Episode 3100 completed.	Last Reward: 1.00	Last 100 Episodes Avarage reward: 0.34		Running reward: 0.40
# Episode 3200 completed.	Last Reward: 0.00	Last 100 Episodes Avarage reward: 0.44		Running reward: 0.50
# Episode 3300 completed.	Last Reward: 0.00	Last 100 Episodes Avarage reward: 0.40		Running reward: 0.38
# Episode 3400 completed.	Last Reward: 0.00	Last 100 Episodes Avarage reward: 0.39		Running reward: 0.44
# Episode 3500 completed.	Last Reward: 0.00	Last 100 Episodes Avarage reward: 0.32		Running reward: 0.29
# Episode 3600 completed.	Last Reward: 0.00	Last 100 Episodes Avarage reward: 0.23		Running reward: 0.24
# Episode 3700 completed.	Last Reward: 0.00	Last 100 Episodes Avarage reward: 0.40		Running reward: 0.41
# Episode 3800 completed.	Last Reward: 0.00	Last 100 Episodes Avarage reward: 0.46		Running reward: 0.32
# Episode 3900 completed.	Last Reward: 0.00	Last 100 Episodes Avarage reward: 0.38		Running reward: 0.30
# Episode 4000 completed.	Last Reward: 0.00	Last 100 Episodes Avarage reward: 0.47		Running reward: 0.48
# Episode 4100 completed.	Last Reward: 1.00	Last 100 Episodes Avarage reward: 0.47		Running reward: 0.51
# Episode 4200 completed.	Last Reward: 1.00	Last 100 Episodes Avarage reward: 0.46		Running reward: 0.46
# Episode 4300 completed.	Last Reward: 0.00	Last 100 Episodes Avarage reward: 0.41		Running reward: 0.39
# Episode 4400 completed.	Last Reward: 0.00	Last 100 Episodes Avarage reward: 0.45		Running reward: 0.35
# Episode 4500 completed.	Last Reward: 0.00	Last 100 Episodes Avarage reward: 0.37		Running reward: 0.26
# Episode 4600 completed.	Last Reward: 0.00	Last 100 Episodes Avarage reward: 0.43		Running reward: 0.48
# Episode 4700 completed.	Last Reward: 2.00	Last 100 Episodes Avarage reward: 0.31		Running reward: 0.52
# Episode 4800 completed.	Last Reward: 1.00	Last 100 Episodes Avarage reward: 0.50		Running reward: 0.51
# Episode 4900 completed.	Last Reward: 0.00	Last 100 Episodes Avarage reward: 0.35		Running reward: 0.44
# Episode 5000 completed.	Last Reward: 0.00	Last 100 Episodes Avarage reward: 0.33		Running reward: 0.21
# Recompensa obtenida en el episodio: 3.0
# Moviepy - Building video temp-{start}.mp4.
# Moviepy - Writing video temp-{start}.mp4
# t:  94%|█████████▍| 235/250 [00:00<00:00, 947.78it/s, now=None] WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file ./output/1747075288.7539747.mp4, 100800 bytes wanted but 0 bytes read,at frame 249/250, at time 8.30/8.30 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
# Moviepy - Done !
# Moviepy - video ready temp-{start}.mp4
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %%
class Policy_6(nn.Module):
    def __init__(self):
        super(Policy_6, self).__init__()

        # Capa convolucional con 3 canales de entrada (RGB)
        self.conv1 = nn.Conv2d(1, 16, kernel_size=8, stride=4)  # 3 canales de entrada (RGB)
        self.conv2 = nn.Conv2d(16, 32, kernel_size=4, stride=2)
        self.conv3 = nn.Conv2d(32, 32, kernel_size=3, stride=1)

        # Capa completamente conectada con la entrada ajustada
        self.fc1 = nn.Linear(32 * 7 * 7, 128)  # 1568 características de entrada
        self.fc2 = nn.Linear(128, 3)  # Número de clases de acción

        self.saved_log_probs = []
        self.rewards = []

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = F.relu(self.conv3(x))

        x = x.reshape(x.size(0), -1)  # Aplanar la salida de las convoluciones

        x = F.relu(self.fc1(x))
        return F.softmax(self.fc2(x), dim=1)


class REINFORCE_6:
  def __init__(self, use_baseline=True, max_steps_per_episode=10000, max_training_episodes=1000):
    self.gamma=0.99
    self.seed=543
    self.render=False
    self.log_interval=10
    #self.env_name=env_name
    self.max_steps_per_episode=max_steps_per_episode
    self.max_training_episodes=max_training_episodes
    self.use_baseline=use_baseline

    self.vidas=-1

    #Crea el ambiente normal
    self.env = gymnasium.make("ALE/Breakout-v5", mode=0, difficulty=0) #Se crea el ambiente.
    obs, _ = self.env.reset()
    torch.manual_seed(self.seed)

    input_dim = obs.shape[0]
    if hasattr(self.env.action_space, 'n'):
      output_dim = self.env.action_space.n
    else:
      raise ValueError("El espacio de acciones debe ser discreto.")

    self.policy = Policy_6()  # Asegúrate de que es la clase adaptada con CNN
    self.optimizer = optim.Adam(self.policy.parameters(), lr=1e-5)  # lr más bajo suele funcionar mejor en imágenes
    self.eps = np.finfo(np.float32).eps.item()  # Para evitar divisiones por cero

  def select_action(self, state, vidas_actuales, epsilon=0.15):
    # Convert the state (environment image) into a PyTorch tensor
    #print("Dimensiones de state antes de torch:", state.shape)
    state = torch.from_numpy(state).float()
    #print("Dimensiones de state después de torch:", state.shape)

    if state.ndimension() == 3:  # (height, width, channels)
        state = np.dot(state[..., :3], [0.2989, 0.5870, 0.1140])  # Convert to grayscale
        state = state[np.newaxis, ...]  # Add channel dimension: (1, H, W)
        state = torch.from_numpy(state).float().unsqueeze(0)  # (1, 1, H, W)
        #print("Dimensiones de state después de grises:", state.shape)
        #state = state.permute(2, 0, 1).unsqueeze(0)  # (1, channels, height, width)

        # Interpolación para redimensionar a 84x84
        state = F.interpolate(state, size=(84, 84), mode='bilinear', align_corners=False)
        #print("Dimensiones después de resize:", state.shape)  # torch.Size([1, 1, 84, 84])


    if(self.vidas == vidas_actuales):
        # Comportamiento epsilon-greedy
        if random.random() < epsilon:  # Con probabilidad epsilon, elegir acción aleatoria
            action = random.choice([0, 1, 2])  # Acción aleatoria (ajusta a tus acciones)
            #print("Acción aleatoria elegida:", action)
        else:
          # Red neuronal elige una acción
          probs = self.policy(state)
          #print(probs)
          m = Categorical(probs)
          action = m.sample()
          self.policy.saved_log_probs.append(m.log_prob(action))
          action = action.item()
        # Mapeo de la acción de la red neuronal a la acción en el juego
        action_map = {0: 0, 1: 2, 2: 3}
        action = action_map[action]
    else:
        # Acción manual (disparar)
        action = 1
        # No registrar log-prob o recompensas para este paso

    # Actualizar vidas para detectar cambios de vidas
    self.vidas = vidas_actuales

    return action

  def finish_episode(self):
    #Version con Baselines
    R = 0
    policy_loss = []
    returns = deque()

    # Calculamos el baseline como el promedio de las recompensas (ESTO HAY QUE CAMBIARLO A ALGO MÁS ÚTIL!!!!)
    if(self.use_baseline):
      baseline = torch.mean(torch.tensor(self.policy.rewards, dtype=torch.float32))
    else:
      baseline=0 #Si self.use_baselines es False, coloca baseline en 0 que es efectivavmente no usar baselines

    for r in self.policy.rewards[::-1]:
        R = r + self.gamma * R
        returns.appendleft(R)
    returns = np.array(returns)  # Convertir la lista a un único numpy array
    returns = torch.tensor(returns)

    # Normalizamos las recompensas con respecto al baseline
    returns = returns - baseline  # Descontamos el baseline de las recompensas

    returns = (returns - returns.mean()) / (returns.std() + self.eps)
    for log_prob, R in zip(self.policy.saved_log_probs, returns):
      if log_prob is not None:
          policy_loss.append(-log_prob * R)

    self.optimizer.zero_grad()

    if len(policy_loss) == 0:
        return  # No se actualiza porque no hubo acciones basadas en la política

    policy_loss = torch.cat(policy_loss).sum()
    policy_loss.backward()
    self.optimizer.step()
    del self.policy.rewards[:]
    del self.policy.saved_log_probs[:]

  def train(self):
    running_reward = 0
    cumulative_episodes_reward=0
    for i_episode in range(1,self.max_training_episodes+1):
        state, _ = self.env.reset()
        self.vidas=-1
        ep_reward = 0
        for t in range(1, self.max_steps_per_episode):  # Don't infinite loop while learning
            vidas_actuales=self.env.unwrapped.ale.lives()
            #print(vidas_actuales)
            action = self.select_action(state=state, vidas_actuales=vidas_actuales)
            #print(action)
            state, reward, terminated, trucated, _ = self.env.step(action)
            done=terminated or trucated

            #if(action==1 and t>1):
            #  reward=-1

            self.policy.rewards.append(reward)
            ep_reward += np.array(reward).item()
            if done:
              break

        running_reward = 0.05 * ep_reward + (1 - 0.05) * running_reward
        cumulative_episodes_reward += ep_reward
        #print("Episode {} Reward: {} and Running Reward: {}".format(i_episode,float(ep_reward),running_reward))
        self.finish_episode()
        if i_episode % self.log_interval == 0:
          print('Episode {} completed.\tLast Reward: {:.2f}\tLast 10 Episodes Avarage reward: {:.2f}\t\tRunning reward: {:.2f}'.format(
                  i_episode, ep_reward, cumulative_episodes_reward/10, running_reward))
          cumulative_episodes_reward=0
        #if self.env.spec.reward_threshold is not None and running_reward > self.env.spec.reward_threshold:
        if running_reward > 10:
          print("Solved! Running reward is now {} and "
                  "the last episode runs to {} time steps!".format(running_reward, t))
          break

  def video(self):
    # Crea un entorno para renderizar
    env = gymnasium.make("ALE/Breakout-v5", render_mode="rgb_array", mode=0, difficulty=0)
    env = renderlab.RenderFrame(env, "./output")

    obs, info = env.reset()
    terminated = False
    truncated = False
    total_reward = 0
    self.vidas=-1

    # Loop de simulación
    while not (terminated or truncated):
        # Elige la acción
        vidas_actuales=env.unwrapped.ale.lives()
        action=self.select_action(obs, vidas_actuales, epsilon=0)

        # Avanza en el entorno real manteniendo la continuidad en el video
        obs, reward, terminated, truncated, info = env.step(action)
        total_reward += reward

    print("Recompensa obtenida en el episodio:", total_reward)
    env.play()


agente_breakout=REINFORCE_6(use_baseline=False,max_steps_per_episode=5000, max_training_episodes=500)
agente_breakout.train()
agente_breakout.video()
# Out:
# WARNING:py.warnings:<ipython-input-73-19883ce4aa57>:63: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments.
#   state = np.dot(state[..., :3], [0.2989, 0.5870, 0.1140])  # Convert to grayscale
# Episode 10 completed.	Last Reward: 4.00	Last 10 Episodes Avarage reward: 1.60		Running reward: 0.66
# Episode 20 completed.	Last Reward: 4.00	Last 10 Episodes Avarage reward: 1.30		Running reward: 0.93
# Episode 30 completed.	Last Reward: 2.00	Last 10 Episodes Avarage reward: 1.40		Running reward: 1.15
# Episode 40 completed.	Last Reward: 1.00	Last 10 Episodes Avarage reward: 1.30		Running reward: 1.20
# Episode 50 completed.	Last Reward: 8.00	Last 10 Episodes Avarage reward: 4.40		Running reward: 2.53
# Episode 60 completed.	Last Reward: 3.00	Last 10 Episodes Avarage reward: 4.50		Running reward: 3.36
# Episode 70 completed.	Last Reward: 5.00	Last 10 Episodes Avarage reward: 5.10		Running reward: 4.10
# Episode 80 completed.	Last Reward: 2.00	Last 10 Episodes Avarage reward: 5.20		Running reward: 4.52
# Episode 90 completed.	Last Reward: 2.00	Last 10 Episodes Avarage reward: 5.20		Running reward: 4.72
# Episode 100 completed.	Last Reward: 3.00	Last 10 Episodes Avarage reward: 5.00		Running reward: 4.77
# Episode 110 completed.	Last Reward: 1.00	Last 10 Episodes Avarage reward: 5.20		Running reward: 4.93
# Episode 120 completed.	Last Reward: 11.00	Last 10 Episodes Avarage reward: 5.60		Running reward: 5.21
# Episode 130 completed.	Last Reward: 4.00	Last 10 Episodes Avarage reward: 5.80		Running reward: 5.45
# Episode 140 completed.	Last Reward: 3.00	Last 10 Episodes Avarage reward: 4.00		Running reward: 4.86
# Episode 150 completed.	Last Reward: 3.00	Last 10 Episodes Avarage reward: 6.20		Running reward: 5.43
# Episode 160 completed.	Last Reward: 7.00	Last 10 Episodes Avarage reward: 6.20		Running reward: 5.69
# Episode 170 completed.	Last Reward: 4.00	Last 10 Episodes Avarage reward: 5.50		Running reward: 5.54
# Episode 180 completed.	Last Reward: 5.00	Last 10 Episodes Avarage reward: 5.20		Running reward: 5.40
# Episode 190 completed.	Last Reward: 11.00	Last 10 Episodes Avarage reward: 6.90		Running reward: 6.06
# Episode 200 completed.	Last Reward: 3.00	Last 10 Episodes Avarage reward: 5.50		Running reward: 5.83
# Episode 210 completed.	Last Reward: 3.00	Last 10 Episodes Avarage reward: 6.80		Running reward: 6.08
# Episode 220 completed.	Last Reward: 3.00	Last 10 Episodes Avarage reward: 5.40		Running reward: 5.81
# Episode 230 completed.	Last Reward: 4.00	Last 10 Episodes Avarage reward: 5.30		Running reward: 5.61
# Episode 240 completed.	Last Reward: 7.00	Last 10 Episodes Avarage reward: 5.60		Running reward: 5.61
# Episode 250 completed.	Last Reward: 3.00	Last 10 Episodes Avarage reward: 4.60		Running reward: 5.18
# Episode 260 completed.	Last Reward: 4.00	Last 10 Episodes Avarage reward: 4.10		Running reward: 4.77
# Episode 270 completed.	Last Reward: 7.00	Last 10 Episodes Avarage reward: 4.10		Running reward: 4.49
# Episode 280 completed.	Last Reward: 7.00	Last 10 Episodes Avarage reward: 4.60		Running reward: 4.56
# Episode 290 completed.	Last Reward: 1.00	Last 10 Episodes Avarage reward: 4.60		Running reward: 4.51
# Episode 300 completed.	Last Reward: 4.00	Last 10 Episodes Avarage reward: 4.70		Running reward: 4.65
# Episode 310 completed.	Last Reward: 6.00	Last 10 Episodes Avarage reward: 4.60		Running reward: 4.64
# Episode 320 completed.	Last Reward: 7.00	Last 10 Episodes Avarage reward: 4.40		Running reward: 4.62
# Episode 330 completed.	Last Reward: 7.00	Last 10 Episodes Avarage reward: 5.30		Running reward: 4.88
# Episode 340 completed.	Last Reward: 0.00	Last 10 Episodes Avarage reward: 4.30		Running reward: 4.68
# Episode 350 completed.	Last Reward: 2.00	Last 10 Episodes Avarage reward: 5.20		Running reward: 4.88
# Episode 360 completed.	Last Reward: 3.00	Last 10 Episodes Avarage reward: 6.00		Running reward: 5.23
# Episode 370 completed.	Last Reward: 7.00	Last 10 Episodes Avarage reward: 5.60		Running reward: 5.34
# Episode 380 completed.	Last Reward: 7.00	Last 10 Episodes Avarage reward: 7.30		Running reward: 6.09
# Episode 390 completed.	Last Reward: 11.00	Last 10 Episodes Avarage reward: 6.90		Running reward: 6.46
# Episode 400 completed.	Last Reward: 2.00	Last 10 Episodes Avarage reward: 6.50		Running reward: 6.38
# Episode 410 completed.	Last Reward: 3.00	Last 10 Episodes Avarage reward: 7.30		Running reward: 6.80
# Episode 420 completed.	Last Reward: 7.00	Last 10 Episodes Avarage reward: 7.00		Running reward: 6.87
# Episode 430 completed.	Last Reward: 7.00	Last 10 Episodes Avarage reward: 5.00		Running reward: 6.15
# Episode 440 completed.	Last Reward: 3.00	Last 10 Episodes Avarage reward: 6.30		Running reward: 6.28
# Episode 450 completed.	Last Reward: 3.00	Last 10 Episodes Avarage reward: 5.20		Running reward: 5.79
# Episode 460 completed.	Last Reward: 8.00	Last 10 Episodes Avarage reward: 7.40		Running reward: 6.40
# Episode 470 completed.	Last Reward: 2.00	Last 10 Episodes Avarage reward: 4.30		Running reward: 5.55
# Episode 480 completed.	Last Reward: 7.00	Last 10 Episodes Avarage reward: 7.10		Running reward: 6.22
# Episode 490 completed.	Last Reward: 3.00	Last 10 Episodes Avarage reward: 5.40		Running reward: 5.83
# Episode 500 completed.	Last Reward: 8.00	Last 10 Episodes Avarage reward: 6.30		Running reward: 6.03
# Recompensa obtenida en el episodio: 11.0
# Moviepy - Building video temp-{start}.mp4.
# Moviepy - Writing video temp-{start}.mp4
# Moviepy - Done !
# Moviepy - video ready temp-{start}.mp4
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %%
class Policy_7(nn.Module):
    def __init__(self):
        super(Policy_7, self).__init__()

        # Capa convolucional con 3 canales de entrada (RGB)
        self.conv1 = nn.Conv2d(1, 16, kernel_size=8, stride=4)  # 3 canales de entrada (RGB)
        self.conv2 = nn.Conv2d(16, 32, kernel_size=4, stride=2)
        self.conv3 = nn.Conv2d(32, 32, kernel_size=3, stride=1)

        # Capa completamente conectada con la entrada ajustada
        self.fc1 = nn.Linear(32 * 7 * 7, 128)  # 1568 características de entrada
        self.fc2 = nn.Linear(128, 3)  # Número de clases de acción

        self.saved_log_probs = []
        self.rewards = []

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = F.relu(self.conv3(x))

        x = x.reshape(x.size(0), -1)  # Aplanar la salida de las convoluciones

        x = F.relu(self.fc1(x))
        #return F.softmax(self.fc2(x), dim=1)
        return self.fc2(x)



class REINFORCE_7:
  def __init__(self, use_baseline=True, max_steps_per_episode=10000, max_training_episodes=1000):
    self.gamma=1 #0.99
    self.seed=543
    self.render=False
    self.log_interval=10
    #self.env_name=env_name
    self.max_steps_per_episode=max_steps_per_episode
    self.max_training_episodes=max_training_episodes
    self.use_baseline=use_baseline

    self.vidas=-1

    #Crea el ambiente normal
    self.env = gymnasium.make("ALE/Breakout-v5", mode=0, difficulty=0) #Se crea el ambiente.
    obs, _ = self.env.reset()
    torch.manual_seed(self.seed)

    input_dim = obs.shape[0]
    if hasattr(self.env.action_space, 'n'):
      output_dim = self.env.action_space.n
    else:
      raise ValueError("El espacio de acciones debe ser discreto.")

    self.policy = Policy_7()  # Asegúrate de que es la clase adaptada con CNN
    self.optimizer = optim.Adam(self.policy.parameters(), lr=1e-5)  # lr más bajo suele funcionar mejor en imágenes
    self.eps = np.finfo(np.float32).eps.item()  # Para evitar divisiones por cero

  def select_action(self, state, vidas_actuales, epsilon=0.15):
    # Convert the state (environment image) into a PyTorch tensor
    #print("Dimensiones de state antes de torch:", state.shape)
    state = torch.from_numpy(state).float()
    #print("Dimensiones de state después de torch:", state.shape)

    if state.ndimension() == 3:  # (height, width, channels)
        state = np.dot(state[..., :3], [0.2989, 0.5870, 0.1140])  # Convert to grayscale
        state = state[np.newaxis, ...]  # Add channel dimension: (1, H, W)
        state = torch.from_numpy(state).float().unsqueeze(0)  # (1, 1, H, W)
        #print("Dimensiones de state después de grises:", state.shape)
        #state = state.permute(2, 0, 1).unsqueeze(0)  # (1, channels, height, width)

        # Interpolación para redimensionar a 84x84
        state = F.interpolate(state, size=(84, 84), mode='bilinear', align_corners=False)
        #print("Dimensiones después de resize:", state.shape)  # torch.Size([1, 1, 84, 84])


    if(self.vidas == vidas_actuales):
        # Comportamiento epsilon-greedy
        if random.random() < epsilon:  # Con probabilidad epsilon, elegir acción aleatoria
            action = random.choice([0, 1, 2])  # Acción aleatoria (ajusta a tus acciones)
            #print("Acción aleatoria elegida:", action)
        else:
          # Red neuronal elige una acción
          """probs = self.policy(state)
          m = Categorical(probs)"""
          logits = self.policy(state)
          m = Categorical(logits=logits)  # más estable
          action = m.sample()
          self.policy.saved_log_probs.append(m.log_prob(action))
          action = action.item()
        # Mapeo de la acción de la red neuronal a la acción en el juego
        action_map = {0: 0, 1: 2, 2: 3}
        action = action_map[action]
    else:
        # Acción manual (disparar)
        action = 1
        # No registrar log-prob o recompensas para este paso

    # Actualizar vidas para detectar cambios de vidas
    self.vidas = vidas_actuales

    return action

  def finish_episode(self):
    #Version con Baselines
    R = 0
    policy_loss = []
    returns = deque()

    # Calculamos el baseline como el promedio de las recompensas (ESTO HAY QUE CAMBIARLO A ALGO MÁS ÚTIL!!!!)
    if(self.use_baseline):
      baseline = torch.mean(torch.tensor(self.policy.rewards, dtype=torch.float32))
    else:
      baseline=0 #Si self.use_baselines es False, coloca baseline en 0 que es efectivavmente no usar baselines

    for r in self.policy.rewards[::-1]:
        R = r + self.gamma * R
        returns.appendleft(R)
    returns = np.array(returns)  # Convertir la lista a un único numpy array
    returns = torch.tensor(returns)

    # Normalizamos las recompensas con respecto al baseline
    returns = returns - baseline  # Descontamos el baseline de las recompensas

    returns = (returns - returns.mean()) / (returns.std() + self.eps)
    for log_prob, R in zip(self.policy.saved_log_probs, returns):
      if log_prob is not None:
          policy_loss.append(-log_prob * R)

    self.optimizer.zero_grad()

    if len(policy_loss) == 0:
        return  # No se actualiza porque no hubo acciones basadas en la política

    policy_loss = torch.cat(policy_loss).sum()
    policy_loss.backward()
    self.optimizer.step()
    del self.policy.rewards[:]
    del self.policy.saved_log_probs[:]

  def train(self):
    running_reward = 0
    cumulative_episodes_reward=0
    for i_episode in range(1,self.max_training_episodes+1):
        state, _ = self.env.reset()
        self.vidas=-1
        ep_reward = 0
        for t in range(1, self.max_steps_per_episode):  # Don't infinite loop while learning
            vidas_actuales=self.env.unwrapped.ale.lives()
            #print(vidas_actuales)
            action = self.select_action(state=state, vidas_actuales=vidas_actuales)
            #print(action)
            state, reward, terminated, trucated, _ = self.env.step(action)
            done=terminated or trucated

            #if(action==1 and t>1):
            #  reward=-1

            self.policy.rewards.append(reward)
            ep_reward += np.array(reward).item()
            if done:
              break

        running_reward = 0.05 * ep_reward + (1 - 0.05) * running_reward
        cumulative_episodes_reward += ep_reward
        #print("Episode {} Reward: {} and Running Reward: {}".format(i_episode,float(ep_reward),running_reward))
        self.finish_episode()
        if i_episode % self.log_interval == 0:
          print('Episode {} completed.\tLast Reward: {:.2f}\tLast 10 Episodes Avarage reward: {:.2f}\t\tRunning reward: {:.2f}'.format(
                  i_episode, ep_reward, cumulative_episodes_reward/10, running_reward))
          cumulative_episodes_reward=0
        #if self.env.spec.reward_threshold is not None and running_reward > self.env.spec.reward_threshold:
        if running_reward > 10:
          print("Solved! Running reward is now {} and "
                  "the last episode runs to {} time steps!".format(running_reward, t))
          break

  def video(self):
    # Crea un entorno para renderizar
    env = gymnasium.make("ALE/Breakout-v5", render_mode="rgb_array", mode=0, difficulty=0)
    env = renderlab.RenderFrame(env, "./output")

    obs, info = env.reset()
    terminated = False
    truncated = False
    total_reward = 0
    self.vidas=-1

    # Loop de simulación
    while not (terminated or truncated):
        # Elige la acción
        vidas_actuales=env.unwrapped.ale.lives()
        action=self.select_action(obs, vidas_actuales, epsilon=0)

        # Avanza en el entorno real manteniendo la continuidad en el video
        obs, reward, terminated, truncated, info = env.step(action)
        total_reward += reward

    print("Recompensa obtenida en el episodio:", total_reward)
    env.play()


agente_breakout=REINFORCE_7(use_baseline=False,max_steps_per_episode=5000, max_training_episodes=1000)
agente_breakout.train()
agente_breakout.video()
# Out:
# WARNING:py.warnings:<ipython-input-9-ad8b3ed707f8>:65: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments.
#   state = np.dot(state[..., :3], [0.2989, 0.5870, 0.1140])  # Convert to grayscale
# Episode 10 completed.	Last Reward: 1.00	Last 10 Episodes Avarage reward: 1.10		Running reward: 0.43
# Episode 20 completed.	Last Reward: 0.00	Last 10 Episodes Avarage reward: 0.60		Running reward: 0.47
# Episode 30 completed.	Last Reward: 1.00	Last 10 Episodes Avarage reward: 1.20		Running reward: 0.79
# Episode 40 completed.	Last Reward: 2.00	Last 10 Episodes Avarage reward: 1.70		Running reward: 1.16
# Episode 50 completed.	Last Reward: 0.00	Last 10 Episodes Avarage reward: 1.60		Running reward: 1.32
# Episode 60 completed.	Last Reward: 2.00	Last 10 Episodes Avarage reward: 1.30		Running reward: 1.35
# Episode 70 completed.	Last Reward: 1.00	Last 10 Episodes Avarage reward: 1.00		Running reward: 1.21
# Episode 80 completed.	Last Reward: 0.00	Last 10 Episodes Avarage reward: 0.80		Running reward: 1.09
# Episode 90 completed.	Last Reward: 1.00	Last 10 Episodes Avarage reward: 1.10		Running reward: 1.06
# Episode 100 completed.	Last Reward: 0.00	Last 10 Episodes Avarage reward: 0.40		Running reward: 0.79
# Episode 110 completed.	Last Reward: 0.00	Last 10 Episodes Avarage reward: 0.70		Running reward: 0.73
# Episode 120 completed.	Last Reward: 2.00	Last 10 Episodes Avarage reward: 1.80		Running reward: 1.19
# Episode 130 completed.	Last Reward: 0.00	Last 10 Episodes Avarage reward: 1.10		Running reward: 1.15
# Episode 140 completed.	Last Reward: 2.00	Last 10 Episodes Avarage reward: 1.50		Running reward: 1.30
# Episode 150 completed.	Last Reward: 0.00	Last 10 Episodes Avarage reward: 1.70		Running reward: 1.45
# Episode 160 completed.	Last Reward: 2.00	Last 10 Episodes Avarage reward: 1.70		Running reward: 1.54
# Episode 170 completed.	Last Reward: 2.00	Last 10 Episodes Avarage reward: 2.10		Running reward: 1.73
# Episode 180 completed.	Last Reward: 2.00	Last 10 Episodes Avarage reward: 3.10		Running reward: 2.29
# Episode 190 completed.	Last Reward: 4.00	Last 10 Episodes Avarage reward: 2.60		Running reward: 2.44
# Episode 200 completed.	Last Reward: 5.00	Last 10 Episodes Avarage reward: 3.50		Running reward: 2.92
# Episode 210 completed.	Last Reward: 3.00	Last 10 Episodes Avarage reward: 4.80		Running reward: 3.67
# Episode 220 completed.	Last Reward: 3.00	Last 10 Episodes Avarage reward: 2.90		Running reward: 3.38
# Episode 230 completed.	Last Reward: 3.00	Last 10 Episodes Avarage reward: 3.90		Running reward: 3.59
# Episode 240 completed.	Last Reward: 2.00	Last 10 Episodes Avarage reward: 3.20		Running reward: 3.43
# Episode 250 completed.	Last Reward: 2.00	Last 10 Episodes Avarage reward: 3.40		Running reward: 3.41
# Episode 260 completed.	Last Reward: 5.00	Last 10 Episodes Avarage reward: 4.30		Running reward: 3.78
# Episode 270 completed.	Last Reward: 2.00	Last 10 Episodes Avarage reward: 3.70		Running reward: 3.71
# Episode 280 completed.	Last Reward: 4.00	Last 10 Episodes Avarage reward: 3.20		Running reward: 3.51
# Episode 290 completed.	Last Reward: 0.00	Last 10 Episodes Avarage reward: 3.50		Running reward: 3.50
# Episode 300 completed.	Last Reward: 3.00	Last 10 Episodes Avarage reward: 4.00		Running reward: 3.65
# Episode 310 completed.	Last Reward: 7.00	Last 10 Episodes Avarage reward: 4.50		Running reward: 3.97
# Episode 320 completed.	Last Reward: 3.00	Last 10 Episodes Avarage reward: 3.40		Running reward: 3.67
# Episode 330 completed.	Last Reward: 3.00	Last 10 Episodes Avarage reward: 4.90		Running reward: 4.16
# Episode 340 completed.	Last Reward: 12.00	Last 10 Episodes Avarage reward: 4.80		Running reward: 4.56
# Episode 350 completed.	Last Reward: 2.00	Last 10 Episodes Avarage reward: 3.60		Running reward: 4.20
# Episode 360 completed.	Last Reward: 2.00	Last 10 Episodes Avarage reward: 4.30		Running reward: 4.26
# Episode 370 completed.	Last Reward: 8.00	Last 10 Episodes Avarage reward: 5.50		Running reward: 4.73
# Episode 380 completed.	Last Reward: 3.00	Last 10 Episodes Avarage reward: 5.30		Running reward: 4.93
# Episode 390 completed.	Last Reward: 1.00	Last 10 Episodes Avarage reward: 4.30		Running reward: 4.68
# Episode 400 completed.	Last Reward: 7.00	Last 10 Episodes Avarage reward: 4.60		Running reward: 4.64
# Episode 410 completed.	Last Reward: 7.00	Last 10 Episodes Avarage reward: 3.70		Running reward: 4.30
# Episode 420 completed.	Last Reward: 3.00	Last 10 Episodes Avarage reward: 3.00		Running reward: 3.84
# Episode 430 completed.	Last Reward: 3.00	Last 10 Episodes Avarage reward: 4.50		Running reward: 4.11
# Episode 440 completed.	Last Reward: 9.00	Last 10 Episodes Avarage reward: 4.00		Running reward: 4.14
# Episode 450 completed.	Last Reward: 3.00	Last 10 Episodes Avarage reward: 4.20		Running reward: 4.14
# Episode 460 completed.	Last Reward: 1.00	Last 10 Episodes Avarage reward: 6.20		Running reward: 4.89
# Episode 470 completed.	Last Reward: 3.00	Last 10 Episodes Avarage reward: 5.90		Running reward: 5.28
# Episode 480 completed.	Last Reward: 2.00	Last 10 Episodes Avarage reward: 5.10		Running reward: 5.12
# Episode 490 completed.	Last Reward: 7.00	Last 10 Episodes Avarage reward: 4.00		Running reward: 4.77
# Episode 500 completed.	Last Reward: 9.00	Last 10 Episodes Avarage reward: 3.60		Running reward: 4.37
# Episode 510 completed.	Last Reward: 3.00	Last 10 Episodes Avarage reward: 4.30		Running reward: 4.27
# Episode 520 completed.	Last Reward: 3.00	Last 10 Episodes Avarage reward: 4.00		Running reward: 4.13
# Episode 530 completed.	Last Reward: 3.00	Last 10 Episodes Avarage reward: 3.20		Running reward: 3.78
# Episode 540 completed.	Last Reward: 3.00	Last 10 Episodes Avarage reward: 3.10		Running reward: 3.54
# Episode 550 completed.	Last Reward: 4.00	Last 10 Episodes Avarage reward: 5.20		Running reward: 4.21
# Episode 560 completed.	Last Reward: 8.00	Last 10 Episodes Avarage reward: 6.50		Running reward: 5.22
# Episode 570 completed.	Last Reward: 4.00	Last 10 Episodes Avarage reward: 5.10		Running reward: 5.19
# Episode 580 completed.	Last Reward: 2.00	Last 10 Episodes Avarage reward: 5.30		Running reward: 5.12
# Episode 590 completed.	Last Reward: 11.00	Last 10 Episodes Avarage reward: 5.10		Running reward: 5.19
# Episode 600 completed.	Last Reward: 7.00	Last 10 Episodes Avarage reward: 4.40		Running reward: 4.89
# Episode 610 completed.	Last Reward: 3.00	Last 10 Episodes Avarage reward: 4.00		Running reward: 4.54
# Episode 620 completed.	Last Reward: 8.00	Last 10 Episodes Avarage reward: 5.30		Running reward: 4.84
# Episode 630 completed.	Last Reward: 2.00	Last 10 Episodes Avarage reward: 5.10		Running reward: 4.95
# Episode 640 completed.	Last Reward: 3.00	Last 10 Episodes Avarage reward: 5.40		Running reward: 5.10
# Episode 650 completed.	Last Reward: 5.00	Last 10 Episodes Avarage reward: 4.90		Running reward: 5.03
# Episode 660 completed.	Last Reward: 3.00	Last 10 Episodes Avarage reward: 4.40		Running reward: 4.78
# Episode 670 completed.	Last Reward: 3.00	Last 10 Episodes Avarage reward: 4.30		Running reward: 4.55
# Episode 680 completed.	Last Reward: 2.00	Last 10 Episodes Avarage reward: 4.70		Running reward: 4.61
# Episode 690 completed.	Last Reward: 7.00	Last 10 Episodes Avarage reward: 5.40		Running reward: 4.91
# Episode 700 completed.	Last Reward: 3.00	Last 10 Episodes Avarage reward: 5.50		Running reward: 5.12
# Episode 710 completed.	Last Reward: 2.00	Last 10 Episodes Avarage reward: 4.30		Running reward: 4.77
# Episode 720 completed.	Last Reward: 7.00	Last 10 Episodes Avarage reward: 6.10		Running reward: 5.38
# Episode 730 completed.	Last Reward: 9.00	Last 10 Episodes Avarage reward: 4.80		Running reward: 5.21
# Episode 740 completed.	Last Reward: 11.00	Last 10 Episodes Avarage reward: 6.10		Running reward: 5.66
# Episode 750 completed.	Last Reward: 2.00	Last 10 Episodes Avarage reward: 3.90		Running reward: 4.88
# Episode 760 completed.	Last Reward: 3.00	Last 10 Episodes Avarage reward: 4.80		Running reward: 4.81
# Episode 770 completed.	Last Reward: 7.00	Last 10 Episodes Avarage reward: 4.90		Running reward: 4.93
# Episode 780 completed.	Last Reward: 3.00	Last 10 Episodes Avarage reward: 5.00		Running reward: 4.92
# Episode 790 completed.	Last Reward: 3.00	Last 10 Episodes Avarage reward: 4.10		Running reward: 4.63
# Episode 800 completed.	Last Reward: 7.00	Last 10 Episodes Avarage reward: 3.80		Running reward: 4.36
# Episode 810 completed.	Last Reward: 6.00	Last 10 Episodes Avarage reward: 5.20		Running reward: 4.64
# Episode 820 completed.	Last Reward: 1.00	Last 10 Episodes Avarage reward: 4.70		Running reward: 4.61
# Episode 830 completed.	Last Reward: 1.00	Last 10 Episodes Avarage reward: 5.30		Running reward: 4.85
# Episode 840 completed.	Last Reward: 3.00	Last 10 Episodes Avarage reward: 5.90		Running reward: 5.24
# Episode 850 completed.	Last Reward: 3.00	Last 10 Episodes Avarage reward: 4.40		Running reward: 4.89
# Episode 860 completed.	Last Reward: 7.00	Last 10 Episodes Avarage reward: 6.50		Running reward: 5.53
# Episode 870 completed.	Last Reward: 7.00	Last 10 Episodes Avarage reward: 5.10		Running reward: 5.39
# Episode 880 completed.	Last Reward: 11.00	Last 10 Episodes Avarage reward: 7.30		Running reward: 6.18
# Episode 890 completed.	Last Reward: 4.00	Last 10 Episodes Avarage reward: 4.00		Running reward: 5.37
# Episode 900 completed.	Last Reward: 4.00	Last 10 Episodes Avarage reward: 5.30		Running reward: 5.30
# Episode 910 completed.	Last Reward: 1.00	Last 10 Episodes Avarage reward: 4.90		Running reward: 5.14
# Episode 920 completed.	Last Reward: 3.00	Last 10 Episodes Avarage reward: 4.90		Running reward: 4.99
# Episode 930 completed.	Last Reward: 5.00	Last 10 Episodes Avarage reward: 4.10		Running reward: 4.66
# Episode 940 completed.	Last Reward: 3.00	Last 10 Episodes Avarage reward: 6.70		Running reward: 5.46
# Episode 950 completed.	Last Reward: 3.00	Last 10 Episodes Avarage reward: 4.40		Running reward: 5.03
# Episode 960 completed.	Last Reward: 2.00	Last 10 Episodes Avarage reward: 4.80		Running reward: 4.98
# Episode 970 completed.	Last Reward: 2.00	Last 10 Episodes Avarage reward: 5.70		Running reward: 5.18
# Episode 980 completed.	Last Reward: 3.00	Last 10 Episodes Avarage reward: 4.90		Running reward: 5.12
# Episode 990 completed.	Last Reward: 4.00	Last 10 Episodes Avarage reward: 4.80		Running reward: 4.95
# Episode 1000 completed.	Last Reward: 1.00	Last 10 Episodes Avarage reward: 5.50		Running reward: 5.22
# Recompensa obtenida en el episodio: 3.0
# Moviepy - Building video temp-{start}.mp4.
# Moviepy - Writing video temp-{start}.mp4
# t:  53%|█████▎    | 114/216 [00:00<00:00, 1083.38it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file ./output/1747082869.1988025.mp4, 100800 bytes wanted but 0 bytes read,at frame 215/216, at time 7.17/7.17 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
# Moviepy - Done !
# Moviepy - video ready temp-{start}.mp4
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %%
class Policy_free(nn.Module):
    def __init__(self):
      super(Policy_free, self).__init__()
      self.conv1 = nn.Conv2d(2, 32, kernel_size=8, stride=4)
      self.bn1 = nn.BatchNorm2d(32)
      self.conv2 = nn.Conv2d(32, 64, kernel_size=4, stride=2)
      self.bn2 = nn.BatchNorm2d(64)
      self.conv3 = nn.Conv2d(64, 64, kernel_size=3, stride=1)
      self.bn3 = nn.BatchNorm2d(64)

      self.fc1 = nn.Linear(64 * 7 * 7, 512)
      self.fc2 = nn.Linear(512, 3)

      self.saved_log_probs = []
      self.rewards = []

    def forward(self, x):
      x = F.relu(self.conv1(x))
      x = F.relu(self.conv2(x))
      x = F.relu(self.conv3(x))

      x = x.reshape(x.size(0), -1)  # Reemplazo de .view()
      x = F.relu(self.fc1(x))
      return F.softmax(self.fc2(x), dim=1)

class REINFORCE_free:
  def __init__(self, use_baseline=True, max_steps_per_episode=10000, max_training_episodes=1000):
    self.gamma=1 #0.99
    self.seed=543
    self.render=False
    self.log_interval=1
    #self.env_name=env_name
    self.max_steps_per_episode=max_steps_per_episode
    self.max_training_episodes=max_training_episodes
    self.use_baseline=use_baseline

    #Crea el ambiente con escala de grises y apilando 4 frames
    self.env = make_atari_env("ALE/Freeway-v5",n_envs=1,seed=0,env_kwargs={"mode": 0, "difficulty": 0})
    self.env = VecFrameStack(self.env, n_stack=2)

    #self.env = gymnasium.make("ALE/Breakout-v5", mode=0, difficulty=0) #Se crea el ambiente.
    #self.env = TimeLimit(self.env, max_episode_steps=max_steps_per_episode)

    #obs, _ = self.env.reset(seed=self.seed)
    obs = self.env.reset()
    torch.manual_seed(self.seed)

    input_dim = obs.shape[0]
    if hasattr(self.env.action_space, 'n'):
      output_dim = self.env.action_space.n
    else:
      raise ValueError("El espacio de acciones debe ser discreto.")

    self.policy = Policy_free()  # Asegúrate de que es la clase adaptada con CNN
    self.optimizer = optim.Adam(self.policy.parameters(), lr=1e-5)  # lr más bajo suele funcionar mejor en imágenes
    self.eps = np.finfo(np.float32).eps.item()  # Para evitar divisiones por cero

  def select_action(self, state, epsilon=0.15):
    # Convert the state (environment image) into a PyTorch tensor
    # state original: (1, 84, 84, 2)
    state = torch.from_numpy(state).float()
    state = state.permute(0, 3, 1, 2)  # state after: (1, 2, 84, 84)


    if random.random() < epsilon:  # Con probabilidad epsilon, elegir acción aleatoria
      action = random.choice([0, 1, 2])  # Acción aleatoria (ajusta a tus acciones)
      #print("Acción aleatoria elegida:", action)
    else:
      # Red neuronal elige una acción
      probs = self.policy(state)
      m = Categorical(probs)
      action = m.sample()
      self.policy.saved_log_probs.append(m.log_prob(action))
      action = action.item()

    return action

  def finish_episode(self):
    #Version con Baselines
    R = 0
    policy_loss = []
    returns = deque()

    # Calculamos el baseline como el promedio de las recompensas (ESTO HAY QUE CAMBIARLO A ALGO MÁS ÚTIL!!!!)
    if(self.use_baseline):
      baseline = torch.mean(torch.tensor(self.policy.rewards, dtype=torch.float32))
    else:
      baseline=0 #Si self.use_baselines es False, coloca baseline en 0 que es efectivavmente no usar baselines

    for r in self.policy.rewards[::-1]:
        R = r + self.gamma * R
        returns.appendleft(R)
    returns = np.array(returns)  # Convertir la lista a un único numpy array
    returns = torch.tensor(returns)

    # Normalizamos las recompensas con respecto al baseline
    returns = returns - baseline  # Descontamos el baseline de las recompensas

    returns = (returns - returns.mean()) / (returns.std() + self.eps)
    for log_prob, R in zip(self.policy.saved_log_probs, returns):
      if log_prob is not None:
          policy_loss.append(-log_prob * R)

    self.optimizer.zero_grad()

    if len(policy_loss) == 0:
        return  # No se actualiza porque no hubo acciones basadas en la política

    policy_loss = torch.cat(policy_loss).sum()
    policy_loss.backward()
    self.optimizer.step()
    del self.policy.rewards[:]
    del self.policy.saved_log_probs[:]

  def train(self):
    running_reward = 0
    #cumulative_episodes_reward=0
    for i_episode in range(1,self.max_training_episodes+1):
        state = self.env.reset()
        ep_reward = 0
        for t in range(1, self.max_steps_per_episode):  # Don't infinite loop while learning
            action = self.select_action(state)
            #print(action)
            state, reward, done, _ = self.env.step([action])
            self.policy.rewards.append(reward)
            ep_reward += np.array(reward).item()
            if done:
              break

        running_reward = 0.05 * ep_reward + (1 - 0.05) * running_reward
        #cumulative_episodes_reward += ep_reward
        #print("Episode {} Reward: {} and Running Reward: {}".format(i_episode,float(ep_reward),running_reward))
        self.finish_episode()
        if i_episode % self.log_interval == 0:
          print('Episode {} completed.\tLast Reward: {:.2f}\tRunning reward: {:.2f}'.format(
                  i_episode, ep_reward, running_reward))
          #cumulative_episodes_reward=0
        #if self.env.spec.reward_threshold is not None and running_reward > self.env.spec.reward_threshold:
        if running_reward > 3:
          print("Solved! Running reward is now {} and "
                  "the last episode runs to {} time steps!".format(running_reward, t))
          break

  def video(self):
    # Crea un entorno para renderizar
    env = gymnasium.make("ALE/Freeway-v5", render_mode="rgb_array", mode=0, difficulty=0)
    env = renderlab.RenderFrame(env, "./output")

    # Frame stack manual para el modelo (apilamos en gris 84x84)
    frame_stack = deque(maxlen=2)

    # Reset del entorno
    obs, info = env.reset()

    # Procesa una copia del frame sólo para el modelo
    def preprocess(obs):
        gray = obs.mean(axis=2).astype(np.uint8)  # escala de grises
        resized = cv2.resize(gray, (84, 84), interpolation=cv2.INTER_AREA)
        return resized

    # Llena el frame stack inicial
    preprocessed = preprocess(obs)
    for _ in range(2):
        frame_stack.append(preprocessed)

    terminated = False
    truncated = False
    total_reward = 0
    self.vidas=-1

    # Loop de simulación
    while not (terminated or truncated):
        # Convertir la pila de frames a la forma (2, 84, 84)
        stacked_obs = np.stack(frame_stack, axis=0)  # (2, 84, 84)

        # Cambiar el orden de las dimensiones a (1, 2, 84, 84) -> (batch_size, channels, height, width)
        stacked_obs = np.expand_dims(stacked_obs, axis=0)  # (1, 2, 84, 84)
        stacked_obs = np.transpose(stacked_obs, (0, 2, 3, 1))  # (1, 84, 84, 2)

        # Elige la acción
        action=self.select_action(stacked_obs, epsilon=0)

        # Avanza en el entorno real manteniendo la continuidad en el video
        obs, reward, terminated, truncated, info = env.step(action)
        total_reward += reward

        # Actualiza el stack sólo para el modelo
        preprocessed = preprocess(obs)
        frame_stack.append(preprocessed)

    print("Recompensa obtenida en el episodio:", total_reward)
    env.play()


agente_freeway=REINFORCE_free(use_baseline=False,max_steps_per_episode=5000, max_training_episodes=100)
agente_freeway.train()
agente_freeway.video()
# Out:
# Episode 1 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 2 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 3 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 4 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 5 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 6 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 7 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 8 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 9 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 10 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 11 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 12 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 13 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 14 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 15 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 16 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 17 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 18 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 19 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 20 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 21 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 22 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 23 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 24 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 25 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 26 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 27 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 28 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 29 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 30 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 31 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 32 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 33 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 34 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 35 completed.	Last Reward: 1.00	Running reward: 0.05
# Episode 36 completed.	Last Reward: 0.00	Running reward: 0.05
# Episode 37 completed.	Last Reward: 1.00	Running reward: 0.10
# Episode 38 completed.	Last Reward: 3.00	Running reward: 0.24
# Episode 39 completed.	Last Reward: 4.00	Running reward: 0.43
# Episode 40 completed.	Last Reward: 6.00	Running reward: 0.71
# Episode 41 completed.	Last Reward: 11.00	Running reward: 1.22
# Episode 42 completed.	Last Reward: 12.00	Running reward: 1.76
# Episode 43 completed.	Last Reward: 15.00	Running reward: 2.42
# Episode 44 completed.	Last Reward: 21.00	Running reward: 3.35
# Solved! Running reward is now 3.3513574313846677 and the last episode runs to 511 time steps!
# Recompensa obtenida en el episodio: 19.0
# Moviepy - Building video temp-{start}.mp4.
# Moviepy - Writing video temp-{start}.mp4
# Moviepy - Done !
# Moviepy - video ready temp-{start}.mp4
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %%
class Policy_free(nn.Module):
    def __init__(self):
      super(Policy_free, self).__init__()
      self.conv1 = nn.Conv2d(2, 32, kernel_size=8, stride=4)
      self.bn1 = nn.BatchNorm2d(32)
      self.conv2 = nn.Conv2d(32, 64, kernel_size=4, stride=2)
      self.bn2 = nn.BatchNorm2d(64)
      self.conv3 = nn.Conv2d(64, 64, kernel_size=3, stride=1)
      self.bn3 = nn.BatchNorm2d(64)

      self.fc1 = nn.Linear(64 * 7 * 7, 512)
      self.fc2 = nn.Linear(512, 3)

      self.saved_log_probs = []
      self.rewards = []

    def forward(self, x):
      x = F.relu(self.conv1(x))
      x = F.relu(self.conv2(x))
      x = F.relu(self.conv3(x))

      x = x.reshape(x.size(0), -1)  # Reemplazo de .view()
      x = F.relu(self.fc1(x))
      return F.softmax(self.fc2(x), dim=1)

class REINFORCE_free:
  def __init__(self, use_baseline=True, max_steps_per_episode=10000, max_training_episodes=1000):
    self.gamma=1 #0.99
    self.seed=543
    self.render=False
    self.log_interval=1
    #self.env_name=env_name
    self.max_steps_per_episode=max_steps_per_episode
    self.max_training_episodes=max_training_episodes
    self.use_baseline=use_baseline

    #Crea el ambiente con escala de grises y apilando 4 frames
    self.env = make_atari_env("ALE/Freeway-v5",n_envs=1,seed=0,env_kwargs={"mode": 0, "difficulty": 0})
    self.env = VecFrameStack(self.env, n_stack=2)

    #self.env = gymnasium.make("ALE/Breakout-v5", mode=0, difficulty=0) #Se crea el ambiente.
    #self.env = TimeLimit(self.env, max_episode_steps=max_steps_per_episode)

    #obs, _ = self.env.reset(seed=self.seed)
    obs = self.env.reset()
    torch.manual_seed(self.seed)

    input_dim = obs.shape[0]
    if hasattr(self.env.action_space, 'n'):
      output_dim = self.env.action_space.n
    else:
      raise ValueError("El espacio de acciones debe ser discreto.")

    self.policy = Policy_free()  # Asegúrate de que es la clase adaptada con CNN
    self.optimizer = optim.Adam(self.policy.parameters(), lr=1e-5)  # lr más bajo suele funcionar mejor en imágenes
    self.eps = np.finfo(np.float32).eps.item()  # Para evitar divisiones por cero

  def select_action(self, state, epsilon=0.15):
    # Convert the state (environment image) into a PyTorch tensor
    # state original: (1, 84, 84, 2)
    state = torch.from_numpy(state).float()
    state = state.permute(0, 3, 1, 2)  # state after: (1, 2, 84, 84)


    if random.random() < epsilon:  # Con probabilidad epsilon, elegir acción aleatoria
      action = random.choice([0, 1, 2])  # Acción aleatoria (ajusta a tus acciones)
      #print("Acción aleatoria elegida:", action)
    else:
      # Red neuronal elige una acción
      probs = self.policy(state)
      m = Categorical(probs)
      action = m.sample()
      self.policy.saved_log_probs.append(m.log_prob(action))
      action = action.item()

    return action

  def finish_episode(self):
    #Version con Baselines
    R = 0
    policy_loss = []
    returns = deque()

    # Calculamos el baseline como el promedio de las recompensas (ESTO HAY QUE CAMBIARLO A ALGO MÁS ÚTIL!!!!)
    if(self.use_baseline):
      baseline = torch.mean(torch.tensor(self.policy.rewards, dtype=torch.float32))
    else:
      baseline=0 #Si self.use_baselines es False, coloca baseline en 0 que es efectivavmente no usar baselines

    for r in self.policy.rewards[::-1]:
        R = r + self.gamma * R
        returns.appendleft(R)
    returns = np.array(returns)  # Convertir la lista a un único numpy array
    returns = torch.tensor(returns)

    # Normalizamos las recompensas con respecto al baseline
    returns = returns - baseline  # Descontamos el baseline de las recompensas

    returns = (returns - returns.mean()) / (returns.std() + self.eps)
    for log_prob, R in zip(self.policy.saved_log_probs, returns):
      if log_prob is not None:
          policy_loss.append(-log_prob * R)

    self.optimizer.zero_grad()

    if len(policy_loss) == 0:
        return  # No se actualiza porque no hubo acciones basadas en la política

    policy_loss = torch.cat(policy_loss).sum()
    policy_loss.backward()
    self.optimizer.step()
    del self.policy.rewards[:]
    del self.policy.saved_log_probs[:]

  def train(self):
    running_reward = 0
    #cumulative_episodes_reward=0
    for i_episode in range(1,self.max_training_episodes+1):
        state = self.env.reset()
        ep_reward = 0
        for t in range(1, self.max_steps_per_episode):  # Don't infinite loop while learning
            action = self.select_action(state, epsilon=0)
            #print(action)
            state, reward, done, _ = self.env.step([action])
            self.policy.rewards.append(reward)
            ep_reward += np.array(reward).item()
            if done:
              break

        running_reward = 0.05 * ep_reward + (1 - 0.05) * running_reward
        #cumulative_episodes_reward += ep_reward
        #print("Episode {} Reward: {} and Running Reward: {}".format(i_episode,float(ep_reward),running_reward))
        self.finish_episode()
        if i_episode % self.log_interval == 0:
          print('Episode {} completed.\tLast Reward: {:.2f}\tRunning reward: {:.2f}'.format(
                  i_episode, ep_reward, running_reward))
          #cumulative_episodes_reward=0
        #if self.env.spec.reward_threshold is not None and running_reward > self.env.spec.reward_threshold:
        if running_reward > 10:
          print("Solved! Running reward is now {} and "
                  "the last episode runs to {} time steps!".format(running_reward, t))
          break

  def video(self):
    # Crea un entorno para renderizar
    env = gymnasium.make("ALE/Freeway-v5", render_mode="rgb_array", mode=0, difficulty=0)
    env = renderlab.RenderFrame(env, "./output")

    # Frame stack manual para el modelo (apilamos en gris 84x84)
    frame_stack = deque(maxlen=2)

    # Reset del entorno
    obs, info = env.reset()

    # Procesa una copia del frame sólo para el modelo
    def preprocess(obs):
        gray = obs.mean(axis=2).astype(np.uint8)  # escala de grises
        resized = cv2.resize(gray, (84, 84), interpolation=cv2.INTER_AREA)
        return resized

    # Llena el frame stack inicial
    preprocessed = preprocess(obs)
    for _ in range(2):
        frame_stack.append(preprocessed)

    terminated = False
    truncated = False
    total_reward = 0
    self.vidas=-1

    # Loop de simulación
    while not (terminated or truncated):
        # Convertir la pila de frames a la forma (2, 84, 84)
        stacked_obs = np.stack(frame_stack, axis=0)  # (2, 84, 84)

        # Cambiar el orden de las dimensiones a (1, 2, 84, 84) -> (batch_size, channels, height, width)
        stacked_obs = np.expand_dims(stacked_obs, axis=0)  # (1, 2, 84, 84)
        stacked_obs = np.transpose(stacked_obs, (0, 2, 3, 1))  # (1, 84, 84, 2)

        # Elige la acción
        action=self.select_action(stacked_obs, epsilon=0)

        # Avanza en el entorno real manteniendo la continuidad en el video
        obs, reward, terminated, truncated, info = env.step(action)
        total_reward += reward

        # Actualiza el stack sólo para el modelo
        preprocessed = preprocess(obs)
        frame_stack.append(preprocessed)

    print("Recompensa obtenida en el episodio:", total_reward)
    env.play()


agente_freeway=REINFORCE_free(use_baseline=False,max_steps_per_episode=5000, max_training_episodes=100)
agente_freeway.train()
agente_freeway.video()
# Out:
# Episode 1 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 2 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 3 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 4 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 5 completed.	Last Reward: 1.00	Running reward: 0.05
# Episode 6 completed.	Last Reward: 0.00	Running reward: 0.05
# Episode 7 completed.	Last Reward: 1.00	Running reward: 0.10
# Episode 8 completed.	Last Reward: 0.00	Running reward: 0.09
# Episode 9 completed.	Last Reward: 0.00	Running reward: 0.09
# Episode 10 completed.	Last Reward: 1.00	Running reward: 0.13
# Episode 11 completed.	Last Reward: 1.00	Running reward: 0.17
# Episode 12 completed.	Last Reward: 6.00	Running reward: 0.47
# Episode 13 completed.	Last Reward: 4.00	Running reward: 0.64
# Episode 14 completed.	Last Reward: 11.00	Running reward: 1.16
# Episode 15 completed.	Last Reward: 11.00	Running reward: 1.65
# Episode 16 completed.	Last Reward: 13.00	Running reward: 2.22
# Episode 17 completed.	Last Reward: 15.00	Running reward: 2.86
# Episode 18 completed.	Last Reward: 17.00	Running reward: 3.57
# Episode 19 completed.	Last Reward: 18.00	Running reward: 4.29
# Episode 20 completed.	Last Reward: 21.00	Running reward: 5.12
# Episode 21 completed.	Last Reward: 18.00	Running reward: 5.77
# Episode 22 completed.	Last Reward: 20.00	Running reward: 6.48
# Episode 23 completed.	Last Reward: 20.00	Running reward: 7.15
# Episode 24 completed.	Last Reward: 20.00	Running reward: 7.80
# Episode 25 completed.	Last Reward: 20.00	Running reward: 8.41
# Episode 26 completed.	Last Reward: 20.00	Running reward: 8.99
# Episode 27 completed.	Last Reward: 20.00	Running reward: 9.54
# Episode 28 completed.	Last Reward: 20.00	Running reward: 10.06
# Solved! Running reward is now 10.06075237908499 and the last episode runs to 505 time steps!
# Recompensa obtenida en el episodio: 21.0
# Moviepy - Building video temp-{start}.mp4.
# Moviepy - Writing video temp-{start}.mp4
# Moviepy - Done !
# Moviepy - video ready temp-{start}.mp4
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %%
class Policy_free(nn.Module):
    def __init__(self):
      super(Policy_free, self).__init__()
      self.conv1 = nn.Conv2d(2, 32, kernel_size=8, stride=4)
      self.bn1 = nn.BatchNorm2d(32)
      self.conv2 = nn.Conv2d(32, 64, kernel_size=4, stride=2)
      self.bn2 = nn.BatchNorm2d(64)
      self.conv3 = nn.Conv2d(64, 64, kernel_size=3, stride=1)
      self.bn3 = nn.BatchNorm2d(64)

      self.fc1 = nn.Linear(64 * 7 * 7, 512)
      self.fc2 = nn.Linear(512, 3)

      self.saved_log_probs = []
      self.rewards = []

    def forward(self, x):
      x = F.relu(self.conv1(x))
      x = F.relu(self.conv2(x))
      x = F.relu(self.conv3(x))

      x = x.reshape(x.size(0), -1)  # Reemplazo de .view()
      x = F.relu(self.fc1(x))
      return F.softmax(self.fc2(x), dim=1)

class REINFORCE_free:
  def __init__(self, use_baseline=True, max_steps_per_episode=10000, max_training_episodes=1000):
    self.gamma=1 #0.99
    self.seed=543
    self.render=False
    self.log_interval=1
    #self.env_name=env_name
    self.max_steps_per_episode=max_steps_per_episode
    self.max_training_episodes=max_training_episodes
    self.use_baseline=use_baseline

    #Crea el ambiente con escala de grises y apilando 4 frames
    self.env = make_atari_env("ALE/Freeway-v5",n_envs=1,seed=0,env_kwargs={"mode": 0, "difficulty": 1})
    self.env = VecFrameStack(self.env, n_stack=2)

    #self.env = gymnasium.make("ALE/Breakout-v5", mode=0, difficulty=0) #Se crea el ambiente.
    #self.env = TimeLimit(self.env, max_episode_steps=max_steps_per_episode)

    #obs, _ = self.env.reset(seed=self.seed)
    obs = self.env.reset()
    torch.manual_seed(self.seed)

    input_dim = obs.shape[0]
    if hasattr(self.env.action_space, 'n'):
      output_dim = self.env.action_space.n
    else:
      raise ValueError("El espacio de acciones debe ser discreto.")

    self.policy = Policy_free()  # Asegúrate de que es la clase adaptada con CNN
    self.optimizer = optim.Adam(self.policy.parameters(), lr=1e-5)  # lr más bajo suele funcionar mejor en imágenes
    self.eps = np.finfo(np.float32).eps.item()  # Para evitar divisiones por cero

  def select_action(self, state, epsilon=0.15):
    # Convert the state (environment image) into a PyTorch tensor
    # state original: (1, 84, 84, 2)
    state = torch.from_numpy(state).float()
    state = state.permute(0, 3, 1, 2)  # state after: (1, 2, 84, 84)


    if random.random() < epsilon:  # Con probabilidad epsilon, elegir acción aleatoria
      action = random.choice([0, 1, 2])  # Acción aleatoria (ajusta a tus acciones)
      #print("Acción aleatoria elegida:", action)
    else:
      # Red neuronal elige una acción
      probs = self.policy(state)
      m = Categorical(probs)
      action = m.sample()
      self.policy.saved_log_probs.append(m.log_prob(action))
      action = action.item()

    return action

  def finish_episode(self):
    #Version con Baselines
    R = 0
    policy_loss = []
    returns = deque()

    # Calculamos el baseline como el promedio de las recompensas (ESTO HAY QUE CAMBIARLO A ALGO MÁS ÚTIL!!!!)
    if(self.use_baseline):
      baseline = torch.mean(torch.tensor(self.policy.rewards, dtype=torch.float32))
    else:
      baseline=0 #Si self.use_baselines es False, coloca baseline en 0 que es efectivavmente no usar baselines

    for r in self.policy.rewards[::-1]:
        R = r + self.gamma * R
        returns.appendleft(R)
    returns = np.array(returns)  # Convertir la lista a un único numpy array
    returns = torch.tensor(returns)

    # Normalizamos las recompensas con respecto al baseline
    returns = returns - baseline  # Descontamos el baseline de las recompensas

    returns = (returns - returns.mean()) / (returns.std() + self.eps)
    for log_prob, R in zip(self.policy.saved_log_probs, returns):
      if log_prob is not None:
          policy_loss.append(-log_prob * R)

    self.optimizer.zero_grad()

    if len(policy_loss) == 0:
        return  # No se actualiza porque no hubo acciones basadas en la política

    policy_loss = torch.cat(policy_loss).sum()
    policy_loss.backward()
    self.optimizer.step()
    del self.policy.rewards[:]
    del self.policy.saved_log_probs[:]

  def train(self):
    running_reward = 0
    #cumulative_episodes_reward=0
    for i_episode in range(1,self.max_training_episodes+1):
        state = self.env.reset()
        ep_reward = 0
        for t in range(1, self.max_steps_per_episode):  # Don't infinite loop while learning
            action = self.select_action(state, epsilon=0)
            #print(action)
            state, reward, done, _ = self.env.step([action])
            self.policy.rewards.append(reward)
            ep_reward += np.array(reward).item()
            if done:
              break

        running_reward = 0.05 * ep_reward + (1 - 0.05) * running_reward
        #cumulative_episodes_reward += ep_reward
        #print("Episode {} Reward: {} and Running Reward: {}".format(i_episode,float(ep_reward),running_reward))
        self.finish_episode()
        if i_episode % self.log_interval == 0:
          print('Episode {} completed.\tLast Reward: {:.2f}\tRunning reward: {:.2f}'.format(
                  i_episode, ep_reward, running_reward))
          #cumulative_episodes_reward=0
        #if self.env.spec.reward_threshold is not None and running_reward > self.env.spec.reward_threshold:
        if running_reward > 15:
          print("Solved! Running reward is now {} and "
                  "the last episode runs to {} time steps!".format(running_reward, t))
          break

  def video(self):
    # Crea un entorno para renderizar
    env = gymnasium.make("ALE/Freeway-v5", render_mode="rgb_array", mode=0, difficulty=1)
    env = renderlab.RenderFrame(env, "./output")

    # Frame stack manual para el modelo (apilamos en gris 84x84)
    frame_stack = deque(maxlen=2)

    # Reset del entorno
    obs, info = env.reset()

    # Procesa una copia del frame sólo para el modelo
    def preprocess(obs):
        gray = obs.mean(axis=2).astype(np.uint8)  # escala de grises
        resized = cv2.resize(gray, (84, 84), interpolation=cv2.INTER_AREA)
        return resized

    # Llena el frame stack inicial
    preprocessed = preprocess(obs)
    for _ in range(2):
        frame_stack.append(preprocessed)

    terminated = False
    truncated = False
    total_reward = 0
    self.vidas=-1

    # Loop de simulación
    while not (terminated or truncated):
        # Convertir la pila de frames a la forma (2, 84, 84)
        stacked_obs = np.stack(frame_stack, axis=0)  # (2, 84, 84)

        # Cambiar el orden de las dimensiones a (1, 2, 84, 84) -> (batch_size, channels, height, width)
        stacked_obs = np.expand_dims(stacked_obs, axis=0)  # (1, 2, 84, 84)
        stacked_obs = np.transpose(stacked_obs, (0, 2, 3, 1))  # (1, 84, 84, 2)

        # Elige la acción
        action=self.select_action(stacked_obs, epsilon=0)

        # Avanza en el entorno real manteniendo la continuidad en el video
        obs, reward, terminated, truncated, info = env.step(action)
        total_reward += reward

        # Actualiza el stack sólo para el modelo
        preprocessed = preprocess(obs)
        frame_stack.append(preprocessed)

    print("Recompensa obtenida en el episodio:", total_reward)
    env.play()


agente_freeway=REINFORCE_free(use_baseline=False,max_steps_per_episode=500, max_training_episodes=1000)
agente_freeway.train()
agente_freeway.video()
# Out:
# Episode 1 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 2 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 3 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 4 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 5 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 6 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 7 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 8 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 9 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 10 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 11 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 12 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 13 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 14 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 15 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 16 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 17 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 18 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 19 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 20 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 21 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 22 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 23 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 24 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 25 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 26 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 27 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 28 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 29 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 30 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 31 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 32 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 33 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 34 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 35 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 36 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 37 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 38 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 39 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 40 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 41 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 42 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 43 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 44 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 45 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 46 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 47 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 48 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 49 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 50 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 51 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 52 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 53 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 54 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 55 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 56 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 57 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 58 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 59 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 60 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 61 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 62 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 63 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 64 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 65 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 66 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 67 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 68 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 69 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 70 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 71 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 72 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 73 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 74 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 75 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 76 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 77 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 78 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 79 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 80 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 81 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 82 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 83 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 84 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 85 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 86 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 87 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 88 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 89 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 90 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 91 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 92 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 93 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 94 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 95 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 96 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 97 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 98 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 99 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 100 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 101 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 102 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 103 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 104 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 105 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 106 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 107 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 108 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 109 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 110 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 111 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 112 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 113 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 114 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 115 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 116 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 117 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 118 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 119 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 120 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 121 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 122 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 123 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 124 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 125 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 126 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 127 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 128 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 129 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 130 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 131 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 132 completed.	Last Reward: 0.00	Running reward: 0.00
# Episode 133 completed.	Last Reward: 1.00	Running reward: 0.05
# Episode 134 completed.	Last Reward: 0.00	Running reward: 0.05
# Episode 135 completed.	Last Reward: 1.00	Running reward: 0.10
# Episode 136 completed.	Last Reward: 0.00	Running reward: 0.09
# Episode 137 completed.	Last Reward: 0.00	Running reward: 0.09
# Episode 138 completed.	Last Reward: 0.00	Running reward: 0.08
# Episode 139 completed.	Last Reward: 0.00	Running reward: 0.08
# Episode 140 completed.	Last Reward: 0.00	Running reward: 0.07
# Episode 141 completed.	Last Reward: 0.00	Running reward: 0.07
# Episode 142 completed.	Last Reward: 0.00	Running reward: 0.07
# Episode 143 completed.	Last Reward: 0.00	Running reward: 0.06
# Episode 144 completed.	Last Reward: 0.00	Running reward: 0.06
# Episode 145 completed.	Last Reward: 0.00	Running reward: 0.06
# Episode 146 completed.	Last Reward: 0.00	Running reward: 0.05
# Episode 147 completed.	Last Reward: 0.00	Running reward: 0.05
# Episode 148 completed.	Last Reward: 0.00	Running reward: 0.05
# Episode 149 completed.	Last Reward: 0.00	Running reward: 0.05
# Episode 150 completed.	Last Reward: 0.00	Running reward: 0.04
# Episode 151 completed.	Last Reward: 0.00	Running reward: 0.04
# Episode 152 completed.	Last Reward: 0.00	Running reward: 0.04
# Episode 153 completed.	Last Reward: 0.00	Running reward: 0.04
# Episode 154 completed.	Last Reward: 0.00	Running reward: 0.04
# Episode 155 completed.	Last Reward: 0.00	Running reward: 0.03
# Episode 156 completed.	Last Reward: 0.00	Running reward: 0.03
# Episode 157 completed.	Last Reward: 0.00	Running reward: 0.03
# Episode 158 completed.	Last Reward: 0.00	Running reward: 0.03
# Episode 159 completed.	Last Reward: 0.00	Running reward: 0.03
# Episode 160 completed.	Last Reward: 0.00	Running reward: 0.03
# Episode 161 completed.	Last Reward: 0.00	Running reward: 0.03
# Episode 162 completed.	Last Reward: 0.00	Running reward: 0.02
# Episode 163 completed.	Last Reward: 0.00	Running reward: 0.02
# Episode 164 completed.	Last Reward: 0.00	Running reward: 0.02
# Episode 165 completed.	Last Reward: 0.00	Running reward: 0.02
# Episode 166 completed.	Last Reward: 0.00	Running reward: 0.02
# Episode 167 completed.	Last Reward: 0.00	Running reward: 0.02
# Episode 168 completed.	Last Reward: 0.00	Running reward: 0.02
# Episode 169 completed.	Last Reward: 0.00	Running reward: 0.02
# Episode 170 completed.	Last Reward: 0.00	Running reward: 0.02
# Episode 171 completed.	Last Reward: 0.00	Running reward: 0.02
# Episode 172 completed.	Last Reward: 0.00	Running reward: 0.01
# Episode 173 completed.	Last Reward: 0.00	Running reward: 0.01
# Episode 174 completed.	Last Reward: 0.00	Running reward: 0.01
# Episode 175 completed.	Last Reward: 0.00	Running reward: 0.01
# Episode 176 completed.	Last Reward: 0.00	Running reward: 0.01
# Episode 177 completed.	Last Reward: 0.00	Running reward: 0.01
# Episode 178 completed.	Last Reward: 0.00	Running reward: 0.01
# Episode 179 completed.	Last Reward: 0.00	Running reward: 0.01
# Episode 180 completed.	Last Reward: 0.00	Running reward: 0.01
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-f3b48955e472> in <cell line: 0>()
#     194
#     195 agente_freeway=REINFORCE_free(use_baseline=False,max_steps_per_episode=500, max_training_episodes=1000)
# --> 196 agente_freeway.train()
#     197 agente_freeway.video()
#
# <ipython-input-26-f3b48955e472> in train(self)
#     131         #cumulative_episodes_reward += ep_reward
#     132         #print("Episode {} Reward: {} and Running Reward: {}".format(i_episode,float(ep_reward),running_reward))
# --> 133         self.finish_episode()
#     134         if i_episode % self.log_interval == 0:
#     135           print('Episode {} completed.\tLast Reward: {:.2f}\tRunning reward: {:.2f}'.format(
#
# <ipython-input-26-f3b48955e472> in finish_episode(self)
#     108
#     109     policy_loss = torch.cat(policy_loss).sum()
# --> 110     policy_loss.backward()
#     111     self.optimizer.step()
#     112     del self.policy.rewards[:]
#
# /usr/local/lib/python3.11/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     624                 inputs=inputs,
#     625             )
# --> 626         torch.autograd.backward(
#     627             self, gradient, retain_graph, create_graph, inputs=inputs
#     628         )
#
# /usr/local/lib/python3.11/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     345     # some Python versions print out the first line of a multi-line function
#     346     # calls in the traceback and some print out the last line
# --> 347     _engine_run_backward(
#     348         tensors,
#     349         grad_tensors_,
#
# /usr/local/lib/python3.11/dist-packages/torch/autograd/graph.py in _engine_run_backward(t_outputs, *args, **kwargs)
#     821         unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     822     try:
# --> 823         return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     824             t_outputs, *args, **kwargs
#     825         )  # Calls into the C++ engine to run the backward pass
#
# KeyboardInterrupt:

# %%
class Policy_atla(nn.Module):
    def __init__(self):
      super(Policy_atla, self).__init__()
      self.conv1 = nn.Conv2d(2, 32, kernel_size=8, stride=4)
      self.bn1 = nn.BatchNorm2d(32)
      self.conv2 = nn.Conv2d(32, 64, kernel_size=4, stride=2)
      self.bn2 = nn.BatchNorm2d(64)
      self.conv3 = nn.Conv2d(64, 64, kernel_size=3, stride=1)
      self.bn3 = nn.BatchNorm2d(64)

      self.fc1 = nn.Linear(64 * 7 * 7, 512)
      self.fc2 = nn.Linear(512, 4)

      self.saved_log_probs = []
      self.rewards = []

    def forward(self, x):
      x = F.relu(self.conv1(x))
      x = F.relu(self.conv2(x))
      x = F.relu(self.conv3(x))

      x = x.reshape(x.size(0), -1)  # Reemplazo de .view()
      x = F.relu(self.fc1(x))
      return F.softmax(self.fc2(x), dim=1)

class REINFORCE_atla:
  def __init__(self, use_baseline=True, max_steps_per_episode=10000, max_training_episodes=1000):
    self.gamma=1 #0.99
    self.seed=543
    self.render=False
    self.log_interval=20
    #self.env_name=env_name
    self.max_steps_per_episode=max_steps_per_episode
    self.max_training_episodes=max_training_episodes
    self.use_baseline=use_baseline

    #Crea el ambiente con escala de grises y apilando 4 frames
    self.env = make_atari_env("ALE/Atlantis-v5",n_envs=1,seed=0,env_kwargs={"mode": 0, "difficulty": 0})
    self.env = VecFrameStack(self.env, n_stack=2)

    #self.env = gymnasium.make("ALE/Breakout-v5", mode=0, difficulty=0) #Se crea el ambiente.
    #self.env = TimeLimit(self.env, max_episode_steps=max_steps_per_episode)

    #obs, _ = self.env.reset(seed=self.seed)
    obs = self.env.reset()
    torch.manual_seed(self.seed)

    input_dim = obs.shape[0]
    if hasattr(self.env.action_space, 'n'):
      output_dim = self.env.action_space.n
    else:
      raise ValueError("El espacio de acciones debe ser discreto.")

    self.policy = Policy_atla()  # Asegúrate de que es la clase adaptada con CNN
    self.optimizer = optim.Adam(self.policy.parameters(), lr=1e-5)  # lr más bajo suele funcionar mejor en imágenes
    self.eps = np.finfo(np.float32).eps.item()  # Para evitar divisiones por cero

  def select_action(self, state, epsilon=0.15):
    # Convert the state (environment image) into a PyTorch tensor
    # state original: (1, 84, 84, 2)
    state = torch.from_numpy(state).float()
    state = state.permute(0, 3, 1, 2)  # state after: (1, 2, 84, 84)


    if random.random() < epsilon:  # Con probabilidad epsilon, elegir acción aleatoria
      action = random.choice([0, 1, 2, 3])  # Acción aleatoria (ajusta a tus acciones)
      #print("Acción aleatoria elegida:", action)
    else:
      # Red neuronal elige una acción
      probs = self.policy(state)
      m = Categorical(probs)
      action = m.sample()
      self.policy.saved_log_probs.append(m.log_prob(action))
      action = action.item()

    return action

  def finish_episode(self):
    #Version con Baselines
    R = 0
    policy_loss = []
    returns = deque()

    # Calculamos el baseline como el promedio de las recompensas (ESTO HAY QUE CAMBIARLO A ALGO MÁS ÚTIL!!!!)
    if(self.use_baseline):
      baseline = torch.mean(torch.tensor(self.policy.rewards, dtype=torch.float32))
    else:
      baseline=0 #Si self.use_baselines es False, coloca baseline en 0 que es efectivavmente no usar baselines

    for r in self.policy.rewards[::-1]:
        R = r + self.gamma * R
        returns.appendleft(R)
    returns = np.array(returns)  # Convertir la lista a un único numpy array
    returns = torch.tensor(returns)

    # Normalizamos las recompensas con respecto al baseline
    returns = returns - baseline  # Descontamos el baseline de las recompensas

    if len(returns) > 1 and returns.std() > 1e-6:
        returns = (returns - returns.mean()) / (returns.std() + self.eps)
    else:
        returns = returns - returns.mean()

    for log_prob, R in zip(self.policy.saved_log_probs, returns):
      if log_prob is not None:
          policy_loss.append(-log_prob * R)

    self.optimizer.zero_grad()

    if len(policy_loss) == 0:
        return  # No se actualiza porque no hubo acciones basadas en la política

    policy_loss = torch.cat(policy_loss).sum()
    policy_loss.backward()
    self.optimizer.step()
    del self.policy.rewards[:]
    del self.policy.saved_log_probs[:]

  def train(self):
    running_reward = 0
    cumulative_episodes_reward=0
    for i_episode in range(1,self.max_training_episodes+1):
        state = self.env.reset()
        ep_reward = 0
        for t in range(1, self.max_steps_per_episode):  # Don't infinite loop while learning
            action = self.select_action(state, epsilon=0)
            #print(action)
            state, reward, done, _ = self.env.step([action])
            self.policy.rewards.append(reward)
            ep_reward += np.array(reward).item()
            if done:
              break

        running_reward = 0.05 * ep_reward + (1 - 0.05) * running_reward
        cumulative_episodes_reward += ep_reward
        #print("Episode {} Reward: {} and Running Reward: {}".format(i_episode,float(ep_reward),running_reward))
        self.finish_episode()
        if i_episode % self.log_interval == 0:
          print('Episode {} completed.\tLast Reward: {:.2f}\tLas 20 Episodes Average Reward: {:.2f}\t\tRunning reward: {:.2f}'.format(
                  i_episode, ep_reward*100, cumulative_episodes_reward*100/20, running_reward*100))
          cumulative_episodes_reward=0
        #if self.env.spec.reward_threshold is not None and running_reward > self.env.spec.reward_threshold:
        if running_reward > 5:
          print("Solved! Running reward is now {} and "
                  "the last episode runs to {} time steps!".format(running_reward*100, t))
          break

  def video(self):
    # Crea un entorno para renderizar
    env = gymnasium.make("ALE/Atlantis-v5", render_mode="rgb_array", mode=0, difficulty=0)
    env = renderlab.RenderFrame(env, "./output")

    # Frame stack manual para el modelo (apilamos en gris 84x84)
    frame_stack = deque(maxlen=2)

    # Reset del entorno
    obs, info = env.reset()

    # Procesa una copia del frame sólo para el modelo
    def preprocess(obs):
        gray = obs.mean(axis=2).astype(np.uint8)  # escala de grises
        resized = cv2.resize(gray, (84, 84), interpolation=cv2.INTER_AREA)
        return resized

    # Llena el frame stack inicial
    preprocessed = preprocess(obs)
    for _ in range(2):
        frame_stack.append(preprocessed)

    terminated = False
    truncated = False
    total_reward = 0
    self.vidas=-1

    # Loop de simulación
    while not (terminated or truncated):
        # Convertir la pila de frames a la forma (2, 84, 84)
        stacked_obs = np.stack(frame_stack, axis=0)  # (2, 84, 84)

        # Cambiar el orden de las dimensiones a (1, 2, 84, 84) -> (batch_size, channels, height, width)
        stacked_obs = np.expand_dims(stacked_obs, axis=0)  # (1, 2, 84, 84)
        stacked_obs = np.transpose(stacked_obs, (0, 2, 3, 1))  # (1, 84, 84, 2)

        # Elige la acción
        action=self.select_action(stacked_obs, epsilon=0)

        # Avanza en el entorno real manteniendo la continuidad en el video
        obs, reward, terminated, truncated, info = env.step(action)
        total_reward += reward

        # Actualiza el stack sólo para el modelo
        preprocessed = preprocess(obs)
        frame_stack.append(preprocessed)

    print("Recompensa obtenida en el episodio:", total_reward)
    env.play()


agente_atlantis=REINFORCE_atla(use_baseline=False,max_steps_per_episode=5000, max_training_episodes=1500)
agente_atlantis.train()
agente_atlantis.video()
# Out:
# Episode 20 completed.	Last Reward: 0.00	Las 20 Episodes Average Reward: 55.00		Running reward: 35.44
# Episode 40 completed.	Last Reward: 0.00	Las 20 Episodes Average Reward: 70.00		Running reward: 60.78
# Episode 60 completed.	Last Reward: 100.00	Las 20 Episodes Average Reward: 80.00		Running reward: 75.00
# Episode 80 completed.	Last Reward: 0.00	Las 20 Episodes Average Reward: 60.00		Running reward: 65.44
# Episode 100 completed.	Last Reward: 100.00	Las 20 Episodes Average Reward: 50.00		Running reward: 53.10
# Episode 120 completed.	Last Reward: 200.00	Las 20 Episodes Average Reward: 40.00		Running reward: 49.16
# Episode 140 completed.	Last Reward: 200.00	Las 20 Episodes Average Reward: 70.00		Running reward: 65.28
# Episode 160 completed.	Last Reward: 0.00	Las 20 Episodes Average Reward: 100.00		Running reward: 93.42
# Episode 180 completed.	Last Reward: 0.00	Las 20 Episodes Average Reward: 105.00		Running reward: 99.09
# Episode 200 completed.	Last Reward: 200.00	Las 20 Episodes Average Reward: 125.00		Running reward: 106.70
# Episode 220 completed.	Last Reward: 0.00	Las 20 Episodes Average Reward: 280.00		Running reward: 227.85
# Episode 240 completed.	Last Reward: 0.00	Las 20 Episodes Average Reward: 200.00		Running reward: 208.70
# Episode 260 completed.	Last Reward: 0.00	Las 20 Episodes Average Reward: 120.00		Running reward: 144.95
# Episode 280 completed.	Last Reward: 0.00	Las 20 Episodes Average Reward: 80.00		Running reward: 109.05
# Episode 300 completed.	Last Reward: 200.00	Las 20 Episodes Average Reward: 120.00		Running reward: 112.35
# Episode 320 completed.	Last Reward: 0.00	Las 20 Episodes Average Reward: 170.00		Running reward: 148.82
# Episode 340 completed.	Last Reward: 0.00	Las 20 Episodes Average Reward: 140.00		Running reward: 144.62
# Episode 360 completed.	Last Reward: 100.00	Las 20 Episodes Average Reward: 180.00		Running reward: 159.99
# Episode 380 completed.	Last Reward: 200.00	Las 20 Episodes Average Reward: 190.00		Running reward: 179.77
# Episode 400 completed.	Last Reward: 100.00	Las 20 Episodes Average Reward: 150.00		Running reward: 153.08
# Episode 420 completed.	Last Reward: 200.00	Las 20 Episodes Average Reward: 185.00		Running reward: 192.33
# Episode 440 completed.	Last Reward: 200.00	Las 20 Episodes Average Reward: 160.00		Running reward: 162.93
# Episode 460 completed.	Last Reward: 0.00	Las 20 Episodes Average Reward: 180.00		Running reward: 181.36
# Episode 480 completed.	Last Reward: 100.00	Las 20 Episodes Average Reward: 200.00		Running reward: 213.60
# Episode 500 completed.	Last Reward: 200.00	Las 20 Episodes Average Reward: 195.00		Running reward: 201.47
# Episode 520 completed.	Last Reward: 0.00	Las 20 Episodes Average Reward: 125.00		Running reward: 147.95
# Episode 540 completed.	Last Reward: 200.00	Las 20 Episodes Average Reward: 75.00		Running reward: 104.17
# Episode 560 completed.	Last Reward: 100.00	Las 20 Episodes Average Reward: 80.00		Running reward: 89.79
# Episode 580 completed.	Last Reward: 100.00	Las 20 Episodes Average Reward: 75.00		Running reward: 74.44
# Episode 600 completed.	Last Reward: 100.00	Las 20 Episodes Average Reward: 60.00		Running reward: 69.39
# Episode 620 completed.	Last Reward: 300.00	Las 20 Episodes Average Reward: 135.00		Running reward: 125.59
# Episode 640 completed.	Last Reward: 0.00	Las 20 Episodes Average Reward: 130.00		Running reward: 121.37
# Episode 660 completed.	Last Reward: 0.00	Las 20 Episodes Average Reward: 170.00		Running reward: 147.02
# Episode 680 completed.	Last Reward: 300.00	Las 20 Episodes Average Reward: 160.00		Running reward: 151.33
# Episode 700 completed.	Last Reward: 0.00	Las 20 Episodes Average Reward: 150.00		Running reward: 163.58
# Episode 720 completed.	Last Reward: 0.00	Las 20 Episodes Average Reward: 95.00		Running reward: 118.95
# Episode 740 completed.	Last Reward: 0.00	Las 20 Episodes Average Reward: 190.00		Running reward: 159.73
# Episode 760 completed.	Last Reward: 300.00	Las 20 Episodes Average Reward: 160.00		Running reward: 146.16
# Episode 780 completed.	Last Reward: 400.00	Las 20 Episodes Average Reward: 135.00		Running reward: 140.96
# Episode 800 completed.	Last Reward: 600.00	Las 20 Episodes Average Reward: 135.00		Running reward: 143.54
# Episode 820 completed.	Last Reward: 100.00	Las 20 Episodes Average Reward: 190.00		Running reward: 169.93
# Episode 840 completed.	Last Reward: 100.00	Las 20 Episodes Average Reward: 120.00		Running reward: 131.15
# Episode 860 completed.	Last Reward: 100.00	Las 20 Episodes Average Reward: 195.00		Running reward: 169.92
# Episode 880 completed.	Last Reward: 300.00	Las 20 Episodes Average Reward: 275.00		Running reward: 229.01
# Episode 900 completed.	Last Reward: 100.00	Las 20 Episodes Average Reward: 175.00		Running reward: 195.99
# Episode 920 completed.	Last Reward: 300.00	Las 20 Episodes Average Reward: 175.00		Running reward: 185.92
# Episode 940 completed.	Last Reward: 0.00	Las 20 Episodes Average Reward: 150.00		Running reward: 166.53
# Episode 960 completed.	Last Reward: 0.00	Las 20 Episodes Average Reward: 175.00		Running reward: 166.58
# Episode 980 completed.	Last Reward: 0.00	Las 20 Episodes Average Reward: 235.00		Running reward: 221.70
# Episode 1000 completed.	Last Reward: 0.00	Las 20 Episodes Average Reward: 110.00		Running reward: 143.16
# Episode 1020 completed.	Last Reward: 300.00	Las 20 Episodes Average Reward: 210.00		Running reward: 193.86
# Episode 1040 completed.	Last Reward: 500.00	Las 20 Episodes Average Reward: 210.00		Running reward: 190.15
# Episode 1060 completed.	Last Reward: 0.00	Las 20 Episodes Average Reward: 230.00		Running reward: 208.54
# Episode 1080 completed.	Last Reward: 100.00	Las 20 Episodes Average Reward: 180.00		Running reward: 195.04
# Episode 1100 completed.	Last Reward: 300.00	Las 20 Episodes Average Reward: 225.00		Running reward: 207.75
# Episode 1120 completed.	Last Reward: 300.00	Las 20 Episodes Average Reward: 235.00		Running reward: 229.86
# Episode 1140 completed.	Last Reward: 0.00	Las 20 Episodes Average Reward: 130.00		Running reward: 160.75
# Episode 1160 completed.	Last Reward: 200.00	Las 20 Episodes Average Reward: 195.00		Running reward: 190.34
# Episode 1180 completed.	Last Reward: 100.00	Las 20 Episodes Average Reward: 170.00		Running reward: 185.86
# Episode 1200 completed.	Last Reward: 400.00	Las 20 Episodes Average Reward: 155.00		Running reward: 171.46
# Episode 1220 completed.	Last Reward: 0.00	Las 20 Episodes Average Reward: 165.00		Running reward: 163.15
# Episode 1240 completed.	Last Reward: 0.00	Las 20 Episodes Average Reward: 180.00		Running reward: 160.99
# Episode 1260 completed.	Last Reward: 300.00	Las 20 Episodes Average Reward: 205.00		Running reward: 178.49
# Episode 1280 completed.	Last Reward: 0.00	Las 20 Episodes Average Reward: 115.00		Running reward: 134.87
# Episode 1300 completed.	Last Reward: 0.00	Las 20 Episodes Average Reward: 160.00		Running reward: 148.22
# Episode 1320 completed.	Last Reward: 100.00	Las 20 Episodes Average Reward: 200.00		Running reward: 167.55
# Episode 1340 completed.	Last Reward: 0.00	Las 20 Episodes Average Reward: 200.00		Running reward: 187.86
# Episode 1360 completed.	Last Reward: 500.00	Las 20 Episodes Average Reward: 245.00		Running reward: 221.60
# Episode 1380 completed.	Last Reward: 300.00	Las 20 Episodes Average Reward: 170.00		Running reward: 198.37
# Episode 1400 completed.	Last Reward: 0.00	Las 20 Episodes Average Reward: 290.00		Running reward: 247.92
# Episode 1420 completed.	Last Reward: 500.00	Las 20 Episodes Average Reward: 295.00		Running reward: 281.10
# Episode 1440 completed.	Last Reward: 600.00	Las 20 Episodes Average Reward: 230.00		Running reward: 262.81
# Episode 1460 completed.	Last Reward: 400.00	Las 20 Episodes Average Reward: 165.00		Running reward: 201.33
# Episode 1480 completed.	Last Reward: 0.00	Las 20 Episodes Average Reward: 200.00		Running reward: 191.32
# Episode 1500 completed.	Last Reward: 0.00	Las 20 Episodes Average Reward: 185.00		Running reward: 178.16
# Recompensa obtenida en el episodio: 15200.0
# Moviepy - Building video temp-{start}.mp4.
# Moviepy - Writing video temp-{start}.mp4
# Moviepy - Done !
# Moviepy - video ready temp-{start}.mp4
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %% [markdown]
# #REINFORCE con baseline

# %% [markdown]
# # Reflexiones Finales

# %% [markdown]
# # Referencias
#
# [1] Sutton, R. S. and Barto, A. G. (2018). Reinforcement Learning: An Introduction. The MIT Press, second edition.
#
# [2] Gym Documentation, Freeway. `https://gymnasium.farama.org/v0.28.1/environments/atari/freeway/`
#
# [3] PyTorch REINFORCE example. `https://github.com/pytorch/examples/blob/main/reinforcement_learning/reinforce.py`
